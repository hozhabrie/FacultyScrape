# %%
import pandas as pd
import requests
import time

# File paths (Updated for UCSF Cancer Center)
file_path = "/Users/elliehozhabri/Documents/RBP/scrape/UCSF_CancerCenter_OpenAlexInput.xlsx"
output_file_path = "/Users/elliehozhabri/Documents/RBP/scrape/UCSF_CancerCenter_OpenAlexResults.xlsx"

# Load the original spreadsheet
df_original = pd.read_excel(file_path)

# Create a new DataFrame with selected columns
columns_to_copy = ["University", "First", "Middle", "Last", "Nickname"]
df_results = df_original[columns_to_copy].copy()

# Add new OpenAlex-related columns
df_results["OpenAlexLink"] = "N/A"
df_results["OpenAlexID"] = "N/A"
df_results["Name Verification"] = "N/A"
df_results["Institute Verification"] = "N/A"
df_results["sameUni"] = "N/A"  # New column to check if institutions match

# OpenAlex API URL
openalex_api_url = "https://api.openalex.org/authors"

def search_openalex(first, last, middle="", nickname=""):
    """Search for an author in OpenAlex using provided names, considering alternative names."""
    query_names = [f"{first} {last}"]
    
    if pd.notna(middle) and middle.strip():
        query_names.append(f"{first} {middle} {last}")
    if pd.notna(nickname) and nickname.strip():
        query_names.append(f"{nickname} {last}")

    for query in query_names:
        try:
            response = requests.get(openalex_api_url, params={"search": query, "per_page": 25}, timeout=10)
            if response.status_code == 200:
                results = response.json().get("results", [])
                return results
        except requests.exceptions.RequestException as e:
            print(f"Error searching OpenAlex for {query}: {e}")
        time.sleep(1)  # Prevent rate limiting
    return []

# Process only the first 10 rows for debugging
for index, row in df_results.iterrows():  # Process only 10 rows
    first, last = row["First"], row["Last"]
    middle = row.get("Middle", "")
    nickname = row.get("Nickname", "")
    university = row["University"]  # University name from original data

    if pd.isna(first) or pd.isna(last):
        continue  # Skip rows with missing names

    print(f"Searching OpenAlex for: {first} {last}")  # Debugging print statement

    results = search_openalex(first, last, middle, nickname)

    if results:
        best_match = None
        best_score = -1  # Track best match score

        for res in results:
            score = 0  # Ranking system

            # Check exact name match (Display Name)
            if res["display_name"].lower() == f"{first} {last}".lower():
                score += 3  # Strong match
            elif middle and res["display_name"].lower() == f"{first} {middle} {last}".lower():
                score += 2  # Middle name match
            elif nickname and res["display_name"].lower() == f"{nickname} {last}".lower():
                score += 1  # Nickname match

            # Check Alternate Names
            if "display_name_alternatives" in res:
                alt_names = [name.lower() for name in res["display_name_alternatives"]]
                if f"{first} {last}".lower() in alt_names:
                    score += 3  # Strong match on alternate name
                elif middle and f"{first} {middle} {last}".lower() in alt_names:
                    score += 2
                elif nickname and f"{nickname} {last}".lower() in alt_names:
                    score += 1

            # Extract all current institutions
            institutions = [inst["institution"]["display_name"] for inst in res.get("affiliations", []) if "institution" in inst]
            past_institutions = [inst["display_name"] for inst in res.get("last_known_institutions", [])] if "last_known_institutions" in res else []

            # Prioritize UCSF and Cancer Center affiliations
            if "University of California, San Francisco" in institutions or "UC San Francisco" in institutions or \
               "UCSF Helen Diller Family Comprehensive Cancer Center" in institutions:
                score += 7  # High priority for UCSF in current institutions
            elif "University of California, San Francisco" in past_institutions or "UC San Francisco" in past_institutions or \
                 "UCSF Helen Diller Family Comprehensive Cancer Center" in past_institutions:
                score += 5  # Moderate priority if UCSF is in past institutions

            # Use OpenAlex's relevance score as a tie-breaker, but with lower weight
            score += res.get("relevance_score", 0) / 2000  # Normalize score, less influence

            if score > best_score:
                best_score = score
                best_match = res  # Select the best-scoring profile

        # If no match is found, fall back to the first result
        if not best_match and results:
            best_match = results[0]

        # Extract OpenAlex ID and verified name
        author_id = best_match["id"].split("/")[-1]
        author_name = best_match["display_name"]

        # Extract all current institutions (before "Past Institutions")
        institutions = []

        if "affiliations" in best_match and best_match["affiliations"]:
            for aff in best_match["affiliations"]:
                if "institution" in aff and "id" in aff["institution"] and "display_name" in aff["institution"]:
                    inst_name = aff["institution"]["display_name"]
                    institutions.append(inst_name)

        # Convert list to a comma-separated string, or set to "N/A" if empty
        institutions_str = ", ".join(institutions) if institutions else "N/A"

        # Compare with the "University" column and set "sameUni" to Y or N
        same_uni = "Y" if "University of California, San Francisco" in institutions_str or \
                          "UC San Francisco" in institutions_str or \
                          "UCSF Helen Diller Family Comprehensive Cancer Center" in institutions_str or \
                          "University of California, San Francisco" in past_institutions or \
                          "UC San Francisco" in past_institutions or \
                          "UCSF Helen Diller Family Comprehensive Cancer Center" in past_institutions else "N"

        # Store extracted data
        df_results.at[index, "OpenAlexLink"] = f"https://openalex.org/authors/{author_id}"
        df_results.at[index, "OpenAlexID"] = author_id
        df_results.at[index, "Name Verification"] = author_name
        df_results.at[index, "Institute Verification"] = institutions_str
        df_results.at[index, "sameUni"] = same_uni  # Y/N check for university match

    else:
        print(f"No OpenAlex match found for {first} {last}")  # Debugging print statement

# Save the new spreadsheet
df_results.to_excel(output_file_path, index=False)

print(f"Debugging complete. Results saved to: {output_file_path}")
# Out:
# Searching OpenAlex for: Shoko Abe
# Searching OpenAlex for: Donald Abrams
# Searching OpenAlex for: Sara Ackerman
# Searching OpenAlex for: Mohamed Adam
# Searching OpenAlex for: Shelley Adler
# Searching OpenAlex for: Armin Afshar
# Searching OpenAlex for: David Agard
# Searching OpenAlex for: Rahul Aggarwal
# Searching OpenAlex for: Manish Aghi
# Searching OpenAlex for: Vicky Agnew
# Searching OpenAlex for: Anurag Agrawal
# Searching OpenAlex for: Weiyun Ai
# Searching OpenAlex for: Rosemary Akhurst
# Searching OpenAlex for: Alain Algazi
# Searching OpenAlex for: Gregory Allen
# Searching OpenAlex for: Steven Altschuler
# Searching OpenAlex for: Michael Alvarado
# Searching OpenAlex for: Edwin Alvarez
# Searching OpenAlex for: Arturo Alvarez-Buylla
# Searching OpenAlex for: Christopher Ames
# Searching OpenAlex for: Raul Andino-Pavlovsky
# Searching OpenAlex for: Charalambos Andreadis
# Searching OpenAlex for: Joaquin Anguera
# Searching OpenAlex for: K. Ansel
# Searching OpenAlex for: Mekhail Anwar
# Searching OpenAlex for: Dorie Apollonio
# Searching OpenAlex for: Mandar Aras
# Searching OpenAlex for: Mehrdad Arjomandi
# Searching OpenAlex for: Michelle Arkin
# Searching OpenAlex for: Shagun Arora
# Searching OpenAlex for: Nancy Ascher
# Searching OpenAlex for: Alan Ashworth
# Searching OpenAlex for: Chloe Atreya
# Searching OpenAlex for: Kimberly Badal
# Searching OpenAlex for: Rick Baehner
# Searching OpenAlex for: Emma Bahroos
# Searching OpenAlex for: Ronald Balassanian
# Searching OpenAlex for: Allan Balmain
# Searching OpenAlex for: Sourav Bandyopadhyay
# Searching OpenAlex for: Anuradha Banerjee
# Searching OpenAlex for: Erin Bank
# Searching OpenAlex for: Diane Barber
# Searching OpenAlex for: Mary Barcellos-Hoff
# Searching OpenAlex for: Jody Baron
# Searching OpenAlex for: Boris Bastian
# Searching OpenAlex for: Amrita Basu
# Searching OpenAlex for: Spencer Behr
# Searching OpenAlex for: Jeffrey Belkora
# Searching OpenAlex for: Brieze Bell
# Searching OpenAlex for: Henrik Bengtsson
# Searching OpenAlex for: Neal Benowitz
# Searching OpenAlex for: Christopher Benz
# Searching OpenAlex for: Mitchel Berger
# Searching OpenAlex for: Emily Bergsland
# Searching OpenAlex for: J. Berry-Lawhorn
# Searching OpenAlex for: Paola Betancur
# Searching OpenAlex for: Aditi Bhargava
# Searching OpenAlex for: Mallar Bhattacharya
# Searching OpenAlex for: Stella Bialous
# Searching OpenAlex for: Daniel Bikle
# Searching OpenAlex for: Kara Bischoff
# Searching OpenAlex for: D. Bissell
# Searching OpenAlex for: Trever Bivona
# Searching OpenAlex for: Elizabeth Blackburn
# Searching OpenAlex for: Collin Blakely
# Searching OpenAlex for: Paul Blanc
# Searching OpenAlex for: Amie Blanco
# Searching OpenAlex for: Robert Blelloch
# Searching OpenAlex for: Jeffrey Bluestone
# Searching OpenAlex for: Robert Bok
# Searching OpenAlex for: Andrew Bollen
# Searching OpenAlex for: Hala Borno
# Searching OpenAlex for: Rohit Bose
# Searching OpenAlex for: Paige Bracci
# Searching OpenAlex for: Benjamin Braun
# Searching OpenAlex for: Steve Braunstein
# Searching OpenAlex for: Laurel Bray-Hanin
# Searching OpenAlex for: Sam Brondfield
# Searching OpenAlex for: Nina Brown
# Searching OpenAlex for: Karen Brungardt
# Searching OpenAlex for: Peter Bruno
# Searching OpenAlex for: Geoffrey Buckle
# Searching OpenAlex for: Matthew Bucknor
# Searching OpenAlex for: Laura Bull
# Searching OpenAlex for: Nancy Burke
# Searching OpenAlex for: Alma Burlingame
# Searching OpenAlex for: Nicholas Butowski
# Searching OpenAlex for: Atul Butte
# Searching OpenAlex for: Nicola Cadenas
# Searching OpenAlex for: Michael Campbell
# Searching OpenAlex for: Julia Carnevale
# Searching OpenAlex for: Peter Carroll
# Searching OpenAlex for: Maria Castellanos
# Searching OpenAlex for: George Caughey
# Searching OpenAlex for: Anna Celli
# Searching OpenAlex for: Soonmee Cha
# Searching OpenAlex for: Benjamin Chaffee
# Searching OpenAlex for: Stephanie Cham
# Searching OpenAlex for: John Chamberlain
# Searching OpenAlex for: Jason Chan
# Searching OpenAlex for: Emily Chan
# Searching OpenAlex for: June Chan
# Searching OpenAlex for: Susan Chang
# Searching OpenAlex for: Maria Chao
# Searching OpenAlex for: Harold Chapman
# Searching OpenAlex for: Jocelyn Chapman
# Searching OpenAlex for: Lee-may Chen
# Searching OpenAlex for: Xu Chen
# Searching OpenAlex for: William Chen
# Searching OpenAlex for: Judy Cheng
# Searching OpenAlex for: Iona Cheng
# Searching OpenAlex for: Michael Cheng
# Searching OpenAlex for: Jing Cheng
# Searching OpenAlex for: Hueylan Chern
# Searching OpenAlex for: A. Chien
# Searching OpenAlex for: Raymond Cho
# Searching OpenAlex for: Dean Chou
# Searching OpenAlex for: Jonathan Chou
# Searching OpenAlex for: Carissa Chu
# Searching OpenAlex for: Jennifer Clarke
# Searching OpenAlex for: Matthew Cooperberg
# Searching OpenAlex for: Jean-Philippe Coppé
# Searching OpenAlex for: Patricia Cornett
# Searching OpenAlex for: Carlos Corvera
# Searching OpenAlex for: Joseph Costello
# Searching OpenAlex for: Shaun Coughlin
# Searching OpenAlex for: Morton Cowan
# Searching OpenAlex for: Charles Craik
# Searching OpenAlex for: Laura Crocitto
# Searching OpenAlex for: Adam Cunha
# Searching OpenAlex for: Thomas Cunningham
# Searching OpenAlex for: Jason Cyster
# Searching OpenAlex for: Lloyd Damon
# Searching OpenAlex for: Teresa Darragh
# Searching OpenAlex for: Adil Daud
# Searching OpenAlex for: John Groot
# Searching OpenAlex for: Ivan Kouchkovsky
# Searching OpenAlex for: Jayanta Debnath
# Searching OpenAlex for: Rebecca DeBoer
# Searching OpenAlex for: Kevin Delucchi
# Searching OpenAlex for: Eric Delwart
# Searching OpenAlex for: Pamela Besten
# Searching OpenAlex for: Arpita Desai
# Searching OpenAlex for: Anand Dhruva
# Searching OpenAlex for: Aaron Diaz
# Searching OpenAlex for: Roberto Díaz
# Searching OpenAlex for: William Dillon
# Searching OpenAlex for: Chieng-Kuang Ding
# No OpenAlex match found for Chieng-Kuang Ding
# Searching OpenAlex for: Niharika Dixit
# Searching OpenAlex for: Daniel Dohan
# Searching OpenAlex for: Meredith Donnelly
# No OpenAlex match found for Meredith Donnelly
# Searching OpenAlex for: David Donner
# Searching OpenAlex for: Quan-Yang Duh
# Searching OpenAlex for: Sophie Dumont
# Searching OpenAlex for: Neil Dunavin
# Searching OpenAlex for: Christopher Dvorak
# Searching OpenAlex for: Cammie Edwards
# Searching OpenAlex for: Bogdan Eftimie
# Searching OpenAlex for: Ivan El-Sayed
# Searching OpenAlex for: R. Elmes
# Searching OpenAlex for: Joanne Engel
# Searching OpenAlex for: Laura Esserman
# Searching OpenAlex for: Michael Evans
# Searching OpenAlex for: Cheryl Ewing
# Searching OpenAlex for: Justin Eyquem
# Searching OpenAlex for: Bruce Faddegon
# Searching OpenAlex for: Zenghua Fan
# Searching OpenAlex for: Stephen Fancy
# Searching OpenAlex for: Faranak Fattahi
# Searching OpenAlex for: Mary Feng
# Searching OpenAlex for: Sandy Feng
# Searching OpenAlex for: Linda Ferrell
# Searching OpenAlex for: Trevor Fidler
# Searching OpenAlex for: Emily Finlayson
# Searching OpenAlex for: Susan Fisher
# Searching OpenAlex for: Robert Flavell
# Searching OpenAlex for: Stephen Floor
# Searching OpenAlex for: Shannon Fogh
# Searching OpenAlex for: Susan Folkman
# Searching OpenAlex for: Barbara Fowble
# Searching OpenAlex for: Stephen Francis
# Searching OpenAlex for: Rony Francois
# Searching OpenAlex for: Christopher Freise
# Searching OpenAlex for: Terence Friedlander
# Searching OpenAlex for: Katherine Fuh
# Searching OpenAlex for: Karin Gaensler
# Searching OpenAlex for: Danica Fujimori
# Searching OpenAlex for: Zev Gartner
# Searching OpenAlex for: Melody Gawliu
# No OpenAlex match found for Melody Gawliu
# Searching OpenAlex for: Karen Gehrman
# No OpenAlex match found for Karen Gehrman
# Searching OpenAlex for: Huimin Geng
# Searching OpenAlex for: Jonathan George
# Searching OpenAlex for: Jason Gestwicki
# Searching OpenAlex for: Jess Ghannam
# Searching OpenAlex for: Kathy Giacomini
# Searching OpenAlex for: Luke Gilbert
# Searching OpenAlex for: Kurt Giles
# Searching OpenAlex for: Ryan Gill
# Searching OpenAlex for: David Glidden
# Searching OpenAlex for: Andrei Goga
# Searching OpenAlex for: Emily Goldberg
# Searching OpenAlex for: Jeffrey Golden
# Searching OpenAlex for: Mindy Goldman
# Searching OpenAlex for: Robert Goldsby
# Searching OpenAlex for: Scarlett Gomez
# Searching OpenAlex for: Hugo Velozo
# Searching OpenAlex for: Hani Goodarzi
# Searching OpenAlex for: John Gordan
# Searching OpenAlex for: Jane Gordon
# Searching OpenAlex for: Jessica Gosnell
# Searching OpenAlex for: Alexander Gottschalk
# Searching OpenAlex for: Rebecca Graff
# Searching OpenAlex for: Jennifer Grandis
# Searching OpenAlex for: Nancy Greenland
# Searching OpenAlex for: Deborah Greenspan
# Searching OpenAlex for: Roy Grekin
# Searching OpenAlex for: Matthew Gribble
# Searching OpenAlex for: Ann Griffin
# Searching OpenAlex for: Matthew Gubens
# Searching OpenAlex for: Nalin Gupta
# Searching OpenAlex for: W. Gustafson
# Searching OpenAlex for: Joseph Guydish
# Searching OpenAlex for: Patrick Ha
# Searching OpenAlex for: Judith Hahn
# Searching OpenAlex for: Sharon Hall
# Searching OpenAlex for: Hobart Harris
# Searching OpenAlex for: Suzanne Harris
# Searching OpenAlex for: Caroline Hastings
# Searching OpenAlex for: Akiko Hata
# Searching OpenAlex for: Erin Hayes
# Searching OpenAlex for: Peng He
# Searching OpenAlex for: Chase Heaton
# Searching OpenAlex for: Mindy Hebert-DeRouen
# Searching OpenAlex for: Matthias Hebrok
# Searching OpenAlex for: Michelle Hermiston
# Searching OpenAlex for: Miguel Pampaloni
# Searching OpenAlex for: Shawn Hervey-Jumper
# Searching OpenAlex for: Steven Hetts
# Searching OpenAlex for: Robert Hiatt
# Searching OpenAlex for: Christine Higham
# Searching OpenAlex for: Joan Hilton
# Searching OpenAlex for: Kenzo Hirose
# Searching OpenAlex for: Ryutaro Hirose
# Searching OpenAlex for: Naomi Hoffer
# Searching OpenAlex for: Julian Hong
# Searching OpenAlex for: Thomas Hope
# Searching OpenAlex for: Andrew Horvai
# Searching OpenAlex for: I-Chow Hsu
# Searching OpenAlex for: Gerald Hsu
# Searching OpenAlex for: Benjamin Huang
# Searching OpenAlex for: Chiung-Yu Huang
# Searching OpenAlex for: Franklin Huang
# Searching OpenAlex for: Joseph Humtsoe
# Searching OpenAlex for: Laura Huppert
# Searching OpenAlex for: Nola Hylton
# Searching OpenAlex for: William Hyun
# Searching OpenAlex for: Thembi Jackson
# No OpenAlex match found for Thembi Jackson
# Searching OpenAlex for: Peyton Jacob
# Searching OpenAlex for: Isha Jain
# Searching OpenAlex for: Jennifer James
# Searching OpenAlex for: Jeroen Jansen
# Searching OpenAlex for: Alexander Johnson
# Searching OpenAlex for: Daniel Johnson
# Searching OpenAlex for: Richard Jordan
# Searching OpenAlex for: Galen Joseph
# Searching OpenAlex for: Timothy Judson
# Searching OpenAlex for: Young-wook Jun
# Searching OpenAlex for: Natalia Jura
# Searching OpenAlex for: Roarke Kamber
# Searching OpenAlex for: Martin Kampmann
# Searching OpenAlex for: Y.W. Kan
# Searching OpenAlex for: Hyunseok Kang
# Searching OpenAlex for: Sang Kang
# Searching OpenAlex for: Celia Kaplan
# Searching OpenAlex for: Lawrence Kaplan
# Searching OpenAlex for: Leah Karliner
# Searching OpenAlex for: Noriyuki Kasahara
# Searching OpenAlex for: Michael Kattah
# Searching OpenAlex for: Bridget Keenan
# Searching OpenAlex for: R. Kelley
# Searching OpenAlex for: Karen Kemby
# No OpenAlex match found for Karen Kemby
# Searching OpenAlex for: Stacey Kenfield
# Searching OpenAlex for: Robert Kerlan
# Searching OpenAlex for: Karla Kerlikowske
# Searching OpenAlex for: Mandana Khalili
# Searching OpenAlex for: Wes Kidder
# Searching OpenAlex for: Grace Kim
# Searching OpenAlex for: Mi-Ok Kim
# Searching OpenAlex for: Kimberly Kirkwood
# Searching OpenAlex for: Sarah Knox
# Searching OpenAlex for: Andrew Ko
# Searching OpenAlex for: Kord Kober
# Searching OpenAlex for: Tanya Kocian
# No OpenAlex match found for Tanya Kocian
# Searching OpenAlex for: Scott Kogan
# Searching OpenAlex for: Krishna Komanduri
# Searching OpenAlex for: Thomas Kornberg
# Searching OpenAlex for: Vadim Koshkin
# Searching OpenAlex for: Johannes Kratz
# Searching OpenAlex for: Deanna Kroetz
# Searching OpenAlex for: Nevan Krogan
# Searching OpenAlex for: Matthew Krummel
# Searching OpenAlex for: Jasleen Kukreja
# Searching OpenAlex for: Sandeep Kunwar
# Searching OpenAlex for: John Kurhanewicz
# Searching OpenAlex for: Matthew Kutys
# Searching OpenAlex for: Daniel Kwon
# Searching OpenAlex for: Natalie Ledesma
# Searching OpenAlex for: Diana Laird
# Searching OpenAlex for: Nahal Lalefar
# Searching OpenAlex for: Nicholas Larocque
# Searching OpenAlex for: Peder Larson
# Searching OpenAlex for: Yun-Fai Lau
# Searching OpenAlex for: Stephen Lazarus
# Searching OpenAlex for: Lorriana Leard
# Searching OpenAlex for: Andrew Leavitt
# Searching OpenAlex for: Philip LeBoit
# Searching OpenAlex for: Jerry Lee
# Searching OpenAlex for: Robin Lee
# Searching OpenAlex for: Hanmin Lee
# Searching OpenAlex for: James Lee
# Searching OpenAlex for: David Lee
# Searching OpenAlex for: Anya Levinson
# Searching OpenAlex for: Jay Levy
# Searching OpenAlex for: Joachim Li
# Searching OpenAlex for: Yan Li
# Searching OpenAlex for: Amy Li
# Searching OpenAlex for: Michael Li
# Searching OpenAlex for: Daniel Lim
# Searching OpenAlex for: Wendell Lim
# Searching OpenAlex for: Hui Lin
# Searching OpenAlex for: Amy Lin
# Searching OpenAlex for: Tracy Lin
# Searching OpenAlex for: Yvonne Lin-Liu
# Searching OpenAlex for: Pamela Ling
# Searching OpenAlex for: Bin Liu
# Searching OpenAlex for: Britt-Marie Ljung
# Searching OpenAlex for: Richard Locksley
# Searching OpenAlex for: Patricia Loftus
# Searching OpenAlex for: Aaron Logan
# Searching OpenAlex for: R. Lokken
# Searching OpenAlex for: Janel Long-Boyle
# Searching OpenAlex for: Mark Looney
# Searching OpenAlex for: Clifford Lowell
# Searching OpenAlex for: Rongze Lu
# Searching OpenAlex for: Janine Lupo
# Searching OpenAlex for: Qihui Lyu
# Searching OpenAlex for: Averil Ma
# Searching OpenAlex for: Yue Ma
# Searching OpenAlex for: Greta Macaire
# Searching OpenAlex for: Hiten Madhani
# Searching OpenAlex for: Mark Magbanua
# Searching OpenAlex for: Sharmila Majumdar
# Searching OpenAlex for: Melanie Majure
# Searching OpenAlex for: Julie Mak
# Searching OpenAlex for: Ajay Maker
# Searching OpenAlex for: Ruth Malone
# Searching OpenAlex for: Michael Mann
# Searching OpenAlex for: Amanda Marinoff
# Searching OpenAlex for: James Marks
# Searching OpenAlex for: Wallace Marshall
# Searching OpenAlex for: Alexander Marson
# Searching OpenAlex for: Jeffrey Martin
# Searching OpenAlex for: Thomas Martin
# Searching OpenAlex for: Katherine Matthay
# Searching OpenAlex for: Aras Mattis
# Searching OpenAlex for: Theodora Mauro
# Searching OpenAlex for: Wendy Max
# Searching OpenAlex for: John McAdams
# Searching OpenAlex for: Lisa McConlogue
# Searching OpenAlex for: Frank McCormick
# Searching OpenAlex for: Donald McDonald
# Searching OpenAlex for: Michael McGrath
# Searching OpenAlex for: Michael McManus
# Searching OpenAlex for: Michelle Melisko
# Searching OpenAlex for: Maxwell Meng
# Searching OpenAlex for: Christine Miaskowski
# Searching OpenAlex for: Jennifer Michlitsch
# Searching OpenAlex for: Kavita Mishra
# Searching OpenAlex for: Laura Miyashita
# No OpenAlex match found for Laura Miyashita
# Searching OpenAlex for: Mark Moasser
# Searching OpenAlex for: Farzad Moazed
# Searching OpenAlex for: Annette Molinaro
# Searching OpenAlex for: David Morgan
# Searching OpenAlex for: Ramin Morshed
# Searching OpenAlex for: Javid Moslehi
# Searching OpenAlex for: Keith Mostov
# Searching OpenAlex for: Emily Mrig
# Searching OpenAlex for: Sabine Mueller
# Searching OpenAlex for: Pratik Mukherjee
# Searching OpenAlex for: Rita Mukhtar
# Searching OpenAlex for: Pamela Munster
# Searching OpenAlex for: Edward Murphy
# Searching OpenAlex for: Eric Nakakura
# Searching OpenAlex for: Jean Nakamura
# Searching OpenAlex for: Mary Nakamura
# Searching OpenAlex for: Kazim Narsinh
# Searching OpenAlex for: Isaac Neuhaus
# Searching OpenAlex for: Nhung Nguyen
# Searching OpenAlex for: Hao Nguyen
# Searching OpenAlex for: Tung Nguyen
# Searching OpenAlex for: Amar Nijagal
# Searching OpenAlex for: Stephen Nishimura
# Searching OpenAlex for: Tomasz Nowakowski
# Searching OpenAlex for: Susan Noworolski
# Searching OpenAlex for: Todd Nystul
# Searching OpenAlex for: Richard O'Donnell
# Searching OpenAlex for: Patrick O'Farrell
# Searching OpenAlex for: Nancy Oberheim Bush
# Searching OpenAlex for: David Oh
# Searching OpenAlex for: Dennis Oh
# Searching OpenAlex for: Hideho Okada
# Searching OpenAlex for: Ross Okimoto
# Searching OpenAlex for: Michael Oldham
# Searching OpenAlex for: Rebecca Olin
# Searching OpenAlex for: Adam Olshen
# Searching OpenAlex for: Susana Ortiz-Urda
# Searching OpenAlex for: Jonathan Ostrem
# Searching OpenAlex for: Regina Otero-Sabogal
# Searching OpenAlex for: Geraldine Pacheco
# Searching OpenAlex for: Alan Paciorek
# Searching OpenAlex for: Joel Palefsky
# Searching OpenAlex for: Nynikka A. Palmer
# Searching OpenAlex for: Catherine Park
# Searching OpenAlex for: John Park
# Searching OpenAlex for: Rena Pasick
# Searching OpenAlex for: Nicole Paulk
# Searching OpenAlex for: Donna Peehl
# Searching OpenAlex for: Melike Pekmezci
# Searching OpenAlex for: Karin Pelka
# Searching OpenAlex for: Tien Peng
# Searching OpenAlex for: Carlos Penilla
# Searching OpenAlex for: Rushika Perera
# Searching OpenAlex for: Cheryl Peretz
# Searching OpenAlex for: Arie Perry
# Searching OpenAlex for: B. Peterlin
# Searching OpenAlex for: Marion Peters
# Searching OpenAlex for: Joanna Phillips
# Searching OpenAlex for: Kathryn Phillips
# Searching OpenAlex for: Sorbarikor Piawah
# Searching OpenAlex for: Russell Pieper
# Searching OpenAlex for: Lisa Ploss
# No OpenAlex match found for Lisa Ploss
# Searching OpenAlex for: Michael Pogrel
# Searching OpenAlex for: Sima Porten
# Searching OpenAlex for: Andrew Posselt
# Searching OpenAlex for: Michael Potter
# Searching OpenAlex for: Michael Prados
# Searching OpenAlex for: Nicolas Prionas
# Searching OpenAlex for: Jennifer Puck
# Searching OpenAlex for: Zoe Quandt
# Searching OpenAlex for: David Quigley
# Searching OpenAlex for: Joseph Rabban III
# No OpenAlex match found for Joseph Rabban III
# Searching OpenAlex for: Michael Rabow
# Searching OpenAlex for: Aleksandar Rajkovic
# Searching OpenAlex for: David Raleigh
# Searching OpenAlex for: Vijay Ramani
# Searching OpenAlex for: Daniel Ramos
# Searching OpenAlex for: Arun Rangaswami
# Searching OpenAlex for: Robert Raphael
# Searching OpenAlex for: Andreas Rauschecker
# Searching OpenAlex for: Alyssa Reddy
# Searching OpenAlex for: Jeremy Reiter
# Searching OpenAlex for: Adam Renslo
# Searching OpenAlex for: Peggy Reynolds
# Searching OpenAlex for: Kim Rhoads
# Searching OpenAlex for: Neil Risch
# Searching OpenAlex for: Mack III
# Searching OpenAlex for: Elizabeth Robbins
# Searching OpenAlex for: John Roberts
# Searching OpenAlex for: Stanley Rogers
# Searching OpenAlex for: Joseph Rohr
# Searching OpenAlex for: Sabrina Ronen
# Searching OpenAlex for: Jeroen Roose
# Searching OpenAlex for: Clark Rosen
# Searching OpenAlex for: Steven Rosen
# Searching OpenAlex for: Michael Rosenblum
# Searching OpenAlex for: Jennifer Rosenbluth
# Searching OpenAlex for: Philip Rosenthal
# Searching OpenAlex for: Susanna Rosi
# Searching OpenAlex for: Ritu Roy
# Searching OpenAlex for: Kole Roybal
# Searching OpenAlex for: James Rubenstein
# Searching OpenAlex for: Davide Ruggero
# Searching OpenAlex for: Hope Rugo
# Searching OpenAlex for: William Ryan
# Searching OpenAlex for: Julie Saba
# Searching OpenAlex for: Amit Sabnis
# Searching OpenAlex for: Urmimala Sarkar
# Searching OpenAlex for: George Sawaya
# Searching OpenAlex for: Rosalyn Sayaman
# Searching OpenAlex for: Peter Sayre
# Searching OpenAlex for: Maren Scheuner
# Searching OpenAlex for: Suzaynn Schick
# Searching OpenAlex for: Nelson Schiller
# Searching OpenAlex for: Dean Schillinger
# Searching OpenAlex for: Hilde Schjerven
# Searching OpenAlex for: Jessica Scholey
# Searching OpenAlex for: Brian Schulte
# Searching OpenAlex for: Bjoern Schwer
# Searching OpenAlex for: Elizabeth Seashore
# Searching OpenAlex for: Jason Sello
# Searching OpenAlex for: Youngho Seo
# Searching OpenAlex for: Jennifer Seuferer
# Searching OpenAlex for: Neil Shah
# Searching OpenAlex for: A. Shain
# Searching OpenAlex for: Kevin Shannon
# Searching OpenAlex for: Salma Shariff-Marco
# Searching OpenAlex for: Wen Shen
# Searching OpenAlex for: Dean Sheppard
# Searching OpenAlex for: Caroline Shiboski
# Searching OpenAlex for: Stephen Shiboski
# Searching OpenAlex for: Kristin Shimano
# Searching OpenAlex for: Katsuto Shinohara
# Searching OpenAlex for: Kevan Shokat
# Searching OpenAlex for: Xiaokun Shu
# Searching OpenAlex for: Marc Shuman
# Searching OpenAlex for: Kate Shumate
# No OpenAlex match found for Kate Shumate
# Searching OpenAlex for: Brian Shy
# Searching OpenAlex for: Amanda Sibley
# Searching OpenAlex for: Edward Sickles
# Searching OpenAlex for: Tara Sigdel
# Searching OpenAlex for: Jeffry Simko
# Searching OpenAlex for: Lisa Singer
# Searching OpenAlex for: Deepika Sirohi
# Searching OpenAlex for: Andrea Skafel
# Searching OpenAlex for: Eric Small
# Searching OpenAlex for: Catherine Smith
# Searching OpenAlex for: James Smith
# Searching OpenAlex for: Rebecca Smith-Bindman
# Searching OpenAlex for: Karen Smith-McCune
# Searching OpenAlex for: Patricia Sneed
# Searching OpenAlex for: David Solomon
# Searching OpenAlex for: Ma Somsouk
# Searching OpenAlex for: Julie Sosa
# Searching OpenAlex for: Matthew Spitzer
# Searching OpenAlex for: Matthew Springer
# Searching OpenAlex for: Renuka Sriram
# Searching OpenAlex for: Gideon Helen
# Searching OpenAlex for: Matthew Stachler
# Searching OpenAlex for: Elliot Stieglitz
# Searching OpenAlex for: Peter Stock
# Searching OpenAlex for: Bradley Stohr
# Searching OpenAlex for: Loretta Strachowski
# Searching OpenAlex for: Robert Stroud
# Searching OpenAlex for: Hai-Yen Sung
# Searching OpenAlex for: Jack Taunton
# Searching OpenAlex for: Andrew Taylor
# Searching OpenAlex for: Jennie Taylor
# Searching OpenAlex for: Margaret Tempero
# Searching OpenAlex for: Jonathan Terdiman
# Searching OpenAlex for: Lisa Thompson
# Searching OpenAlex for: Jeffrey Tice
# Searching OpenAlex for: Luika Timmerman
# Searching OpenAlex for: Thea Tlsty
# Searching OpenAlex for: David Toczyski
# Searching OpenAlex for: Patrick Treseler
# Searching OpenAlex for: Katy Tsai
# Searching OpenAlex for: Janice Tsoh
# Searching OpenAlex for: Sharof Tugizov
# Searching OpenAlex for: Peter Turnbaugh
# Searching OpenAlex for: Aaron Tward
# Searching OpenAlex for: Stefanie Ueda
# Searching OpenAlex for: Erik Ullian
# Searching OpenAlex for: Anatoly Urisman
# Searching OpenAlex for: Christian Vaisse
# Searching OpenAlex for: Laura van 't Veer
# Searching OpenAlex for: Erin Blarigan
# Searching OpenAlex for: Katherine Loon
# Searching OpenAlex for: Henry VanBrocklin
# Searching OpenAlex for: Scott Vandenberg
# Searching OpenAlex for: Madhulika Varma
# Searching OpenAlex for: Harish Vasudevan
# Searching OpenAlex for: Ana Mañana
# Searching OpenAlex for: Alan Venook
# Searching OpenAlex for: Kliment Verba
# Searching OpenAlex for: Daniel Vigneron
# Searching OpenAlex for: Maya Vijayaraghavan
# Searching OpenAlex for: Alessandro Villa
# Searching OpenAlex for: Javier Villanueva-Meyer
# Searching OpenAlex for: Pavithra Viswanath
# Searching OpenAlex for: Kieuhoa Vo
# Searching OpenAlex for: Daniel Wagner
# Searching OpenAlex for: Katherine Wai
# Searching OpenAlex for: Judith Walsh
# Searching OpenAlex for: Louise Walter
# Searching OpenAlex for: Peter Walter
# Searching OpenAlex for: Mark Walters
# Searching OpenAlex for: Lei Wang
# Searching OpenAlex for: Victoria Wang
# Searching OpenAlex for: Zhen Wang
# Searching OpenAlex for: Bruce Wang
# Searching OpenAlex for: Chia-Ching Wang
# Searching OpenAlex for: Rong Wang
# Searching OpenAlex for: Sunny Wang
# Searching OpenAlex for: Robert Warren
# Searching OpenAlex for: Samuel Washington III
# Searching OpenAlex for: Catherine Waters
# Searching OpenAlex for: Valerie Weaver
# Searching OpenAlex for: Ying Wei
# Searching OpenAlex for: Maria Wei
# Searching OpenAlex for: Arthur Weiss
# Searching OpenAlex for: William Weiss
# Searching OpenAlex for: James Wells
# Searching OpenAlex for: Kwun Wen
# Searching OpenAlex for: Justin White
# Searching OpenAlex for: Martha White
# Searching OpenAlex for: John Wiencke
# Searching OpenAlex for: Arun Wiita
# Searching OpenAlex for: James Wilkins
# Searching OpenAlex for: Holger Willenbring
# Searching OpenAlex for: Lindsay Williams
# Searching OpenAlex for: Lena Winestone
# Searching OpenAlex for: Beth Winger
# Searching OpenAlex for: Torsten Wittmann
# Searching OpenAlex for: Jeffrey Wolf
# Searching OpenAlex for: Jasmine Wong
# Searching OpenAlex for: Margaret Wrensch
# Searching OpenAlex for: Natalie Wu
# Searching OpenAlex for: Lani Wu
# Searching OpenAlex for: Rosanna Wustrack
# Searching OpenAlex for: Melisa Wong
# Searching OpenAlex for: Keith Yamamoto
# Searching OpenAlex for: Francis Yao
# Searching OpenAlex for: Tingting Yao
# Searching OpenAlex for: Christina Yau
# Searching OpenAlex for: Yerem Yeghiazarians
# Searching OpenAlex for: Benjamin Yeh
# Searching OpenAlex for: Iwei Yeh
# Searching OpenAlex for: Valerie Yerger
# Searching OpenAlex for: Sue Yom
# Searching OpenAlex for: Emi Yoshida
# Searching OpenAlex for: Liang You
# Searching OpenAlex for: Darrell Young
# Searching OpenAlex for: Jacob Young
# Searching OpenAlex for: Elizabeth Young
# Searching OpenAlex for: Tina Yu
# Searching OpenAlex for: Lydia Zablotska
# Searching OpenAlex for: Charles Zaloudek
# Searching OpenAlex for: Balyn Zaro
# Searching OpenAlex for: Li Zhang
# Searching OpenAlex for: Yu Zhou
# Searching OpenAlex for: Xiaolin Zhu
# Searching OpenAlex for: Elad Ziv
# Debugging complete. Results saved to: /Users/elliehozhabri/Documents/RBP/scrape/UCSF_CancerCenter_OpenAlexResults.xlsx
