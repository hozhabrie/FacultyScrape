# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import subprocess

# Prevent system sleep using caffeinate
caffeinate_process = subprocess.Popen(["caffeinate", "-d"])  # Keeps Mac awake during script execution

# List of STEM departments to filter
stem_keywords = [
    "Science", "Engineering", "Mathematics", "Technology", "Biology", "Physics", "Chemistry",
    "Geology", "Astronomy", "Astrophysics", "Neuroscience", "Genetics", "Ecology", "Evolution",
    "Cybersecurity", "Data", "Computer", "Computer Science", "Artificial Intelligence", 
    "Machine Learning", "Robotics", "Statistics", "Analytics", "Actuarial", "Operations Research",
    "Materials", "Nanotechnology", "Bioinformatics", "Cognitive", "Mechatronics", "Systems",
    "Geography", "Astrophysical", "Planetary", "Public Health", "Clinical", "Integrative Physiology",
    "Chemical", "Biological", "Medicine", "Medical", "Psychiatry"
]

# Function to get faculty details
def get_faculty_info(profile_url, listing_name, count):
    try:
        response = requests.get(profile_url, headers={"User-Agent": "Mozilla/5.0"})
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract name from title tag
        name_section = soup.find("title")
        profile_name = name_section.get_text(strip=True).split("|")[0] if name_section else "Name not found"
        
        # Compare names and keep the more detailed one
        full_name = profile_name if len(profile_name) > len(listing_name) else listing_name
        print(f"Selected name: {full_name}")
        
        if not full_name or full_name == 'Name not found':
            print(f"Failed to extract name from: {profile_url}")
            return "", "", "", "", ""
        
        # Ensure correct splitting of names
        if ", " in full_name:
            last_name, first_middle = full_name.split(", ", 1)
            first_middle_parts = first_middle.split(" ")
            first_name = first_middle_parts[0]
            middle_name = " ".join(first_middle_parts[1:]).replace(".", "") if len(first_middle_parts) > 1 else ""
        else:
            last_name = full_name
            first_name, middle_name = "", ""
        
        # Extract department (handling multiple positions)
        departments = []
        positions = soup.select("ul#individual-personInPosition li[role='listitem']")
        for position in positions:
            title_text = position.get_text(strip=True)
            if any(keyword in title_text for keyword in ["Professor", "Dean", "Director"]):
                dept_link = position.find("a")
                if dept_link:
                    departments.append(dept_link.get_text(strip=True))
        department = ", ".join(departments) if departments else "Department not found"
        
        # Determine if the faculty member belongs to a STEM department
        is_stem = "Y" if any(stem in department for stem in stem_departments) else "N"
        
        return first_name, middle_name, last_name, department, is_stem
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {profile_url}: {e}")
        return "", "", "", "", ""

# Base URL for UC Boulder Faculty A-Z Catalog
base_url = "https://catalog.colorado.edu/faculty-a-z/"
faculty_data = []

print("Scraping faculty directory...")
response = requests.get(base_url, headers={"User-Agent": "Mozilla/5.0"})
response.raise_for_status()
soup = BeautifulSoup(response.text, 'html.parser')

# Find faculty listings
faculty_list = soup.select("a[href*='experts.colorado.edu']")
print(f"Found {len(faculty_list)} faculty links")

for count, faculty in enumerate(faculty_list, start=1):
    listing_name = faculty.get_text(strip=True)
    print(f"Extracted name from listing: {listing_name}")
    
    profile_link = faculty["href"]
    if not profile_link.startswith("http"):
        profile_link = "https://experts.colorado.edu" + profile_link  # Ensure full URL
    
    first_name, middle_name, last_name, department, is_stem = get_faculty_info(profile_link, listing_name, count)
    
    if first_name and last_name:  # Skip entries with errors
        faculty_data.append(["University of Colorado Boulder", first_name, middle_name, last_name, department, is_stem, profile_link])
    
    time.sleep(1)  # Avoid overwhelming the server

# Save to Excel
output_file = "uc_boulder_faculty2.xlsx"
df = pd.DataFrame(faculty_data, columns=["University", "First", "Middle", "Last", "Department", "isSTEM", "Link"])
print(f"Total extracted records: {len(faculty_data)}")
df.to_excel(output_file, index=False)
print(f"Faculty list saved to {output_file}")

# Stop preventing sleep
caffeinate_process.terminate()
# Out:
# Scraping faculty directory...
# Found 1923 faculty links
# Extracted name from listing: Aaronson, Norman F.
# Selected name: Aaronson, Norman F.
# Extracted name from listing: Abbott, Lon D.
# Selected name: Abbott, Lon D.
# Extracted name from listing: Abdalati, Waleed
# Selected name: Abdalati, Waleed
# Extracted name from listing: Abdullah, Aamir
# Error fetching https://experts.colorado.edu/display/fisid_167490: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_167490
# Extracted name from listing: Abiragi, Anthony A.
# Selected name: Abiragi, Anthony A.
# Extracted name from listing: Ablowitz, Mark J.
# Selected name: Ablowitz, Mark J.
# Extracted name from listing: Acevedo-Muñoz, Ernesto R.
# Selected name: Acevedo-Muñoz, Ernesto R.
# Extracted name from listing: Ackerman, John Martin
# Selected name: Ackerman, John Martin
# Extracted name from listing: Ackland, Len
# Selected name: Ackland, Len
# Extracted name from listing: Adams, Heather L.
# Selected name: Adams, Heather L.
# Extracted name from listing: Adams, Sharon Mar
# Selected name: Adams, Sharon Mar
# Extracted name from listing: Adams, William
# Selected name: Adams, William  Walter, III
# Extracted name from listing: Adler, Edward Scott
# Selected name: Adler, Edward Scott
# Extracted name from listing: Affrunti, Andrew J.
# Selected name: Affrunti, Andrew Joseph
# Extracted name from listing: Agnoletti, Charla
# Error fetching https://experts.colorado.edu/display/fisid_156405: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_156405
# Extracted name from listing: Aguliera, Arthur
# Selected name: Aguilera, Arthur
# Extracted name from listing: Ahmed, Alaa A.
# Selected name: Ahmed, Alaa Abdalla
# Extracted name from listing: Ahmed, Nisar R.
# Selected name: Ahmed, Nisar Razzi
# Extracted name from listing: Ahn, Natalie
# Selected name: Ahn, Natalie
# Extracted name from listing: Akos, Dennis M.
# Selected name: Akos, Dennis M.
# Extracted name from listing: Albert, Michelle A.
# Selected name: Albert, Michelle A.
# Extracted name from listing: Aldama, Arturo James
# Selected name: Aldama, Arturo James
# Extracted name from listing: Alderete, Tanya Lynn
# Error fetching https://experts.colorado.edu/display/fisid_159723: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_159723
# Extracted name from listing: Alexander, Katherine Laura Bos
# Selected name: Alexander, Katherine Laura Bos
# Extracted name from listing: Alhadeff, Albert
# Selected name: Alhadeff, Albert
# Extracted name from listing: Ali, Aun Hasan
# Selected name: Ali, Aun Hasan
# Extracted name from listing: Ali, Hisham
# Selected name: Ali, Hisham
# Extracted name from listing: Alistar, Mirela
# Selected name: Alistar, Mirela
# Extracted name from listing: Allen, David
# Selected name: Allen, David Lehigh
# Extracted name from listing: Allmendinger, Katerina
# Selected name: Allmendinger, Katerina
# Extracted name from listing: Alpern, Tyler J.
# Selected name: Alpern, Tyler J.
# Extracted name from listing: Alston, Eric Christopher
# Selected name: Alston, Eric Christopher
# Extracted name from listing: Amadei, Bernard
# Selected name: Amadei, Bernard
# Extracted name from listing: Ambler, Wayne
# Selected name: Ambler, Wayne
# Extracted name from listing: Ambrose, Kirk T.
# Selected name: Ambrose, Kirk T.
# Extracted name from listing: Amerika, Mark
# Selected name: Amerika, Mark
# Extracted name from listing: Anaya, S. James
# Selected name: Anaya, S. James
# Extracted name from listing: Anderman, Elizabeth
# Error fetching https://experts.colorado.edu/display/fisid_144257: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_144257
# Extracted name from listing: Anderson, Brandon
# Selected name: Anderson, Brandon
# Extracted name from listing: Anderson, Dana Z.
# Selected name: Anderson, Dana Z.
# Extracted name from listing: Anderson, Fred W.
# Selected name: Anderson, Fred W.
# Extracted name from listing: Anderson, Kenneth M.
# Selected name: Anderson, Kenneth M.
# Extracted name from listing: Anderson, Robert S.
# Selected name: Anderson, Robert S.
# Extracted name from listing: Anderson, Suzanne Prestrud
# Selected name: Anderson, Suzanne Prestrud
# Extracted name from listing: Anderson, Virginia D.
# Selected name: Anderson, Virginia DeJohn
# Extracted name from listing: Andersson, Krister Par
# Error fetching https://experts.colorado.edu/display/fisid_140076: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_140076
# Extracted name from listing: André, Quentin
# Selected name: André, Quentin
# Extracted name from listing: Andrews, Thomas G.
# Selected name: Andrews, Thomas G.
# Extracted name from listing: Anseth, Kristi S.
# Selected name: Anseth, Kristi S.
# Extracted name from listing: Antman, Francisca Marie
# Selected name: Antman, Francisca Marie
# Extracted name from listing: Appelö, Daniel E.
# Selected name: Appelö, Daniel E.
# Extracted name from listing: Arch, Joanna
# Selected name: Arch, Joanna
# Extracted name from listing: Ardizzoni, Michela
# Selected name: Ardizzoni, Michela
# Extracted name from listing: Arehart, Joseph Hoberg
# Selected name: Arehart, Joseph Hoberg
# Extracted name from listing: Arehart, Kathryn H.
# Selected name: Arehart, Kathryn H.
# Extracted name from listing: Argrow, Brian M.
# Selected name: Argrow, Brian M.
# Extracted name from listing: Arnoult, Nausica Christine
# Selected name: Arnoult, Nausica Christine
# Extracted name from listing: Arp, Jared
# Selected name: Arp, Jared
# Extracted name from listing: Arquilla, Katya
# Selected name: Arquilla, Katya Sofia
# Extracted name from listing: Arthurs, Leilani A.
# Selected name: Arthurs, Leilani A.
# Extracted name from listing: Arya, Nidhi
# Selected name: Arya, Nidhi
# Extracted name from listing: Asano, Yukiko
# Selected name: Asano, Yukiko
# Extracted name from listing: Ashcraft, Karen Lee
# Selected name: Ashcraft, Karen Lee
# Extracted name from listing: Asirvatham, Margaret
# Selected name: Asirvatham, Margaret
# Extracted name from listing: Atnally, Diane L.
# Selected name: Conlin, Diane Atnally
# Extracted name from listing: Attwa, Mona Farrag
# Selected name: Attwa, Mona Farrag
# Extracted name from listing: Auguiste, Reece Luke
# Selected name: Auguiste, Reece Luke
# Extracted name from listing: Auslander, Bonnie
# Selected name: Auslander, Bonnie
# Extracted name from listing: Austin, James R.
# Selected name: Austin, James R.
# Extracted name from listing: Auvinen, Karen Marie
# Selected name: Auvinen, Karen Marie
# Extracted name from listing: Avila, Sara
# Selected name: Avila Forcada, Sara
# Extracted name from listing: Axelrad, Penina
# Selected name: Axelrad, Penina
# Extracted name from listing: Aydin, Aysegul
# Selected name: Aydin, Aysegul
# Extracted name from listing: Aydin, Halil
# Selected name: Aydin, Halil
# Extracted name from listing: Babicz, Martin Charles
# Selected name: Babicz, Martin Charles
# Extracted name from listing: Bacalzo, Dean
# Selected name: Bacalzo, Dean
# Extracted name from listing: Bachtell, Ryan
# Selected name: Bachtell, Ryan
# Extracted name from listing: Baiduc, Rachael
# Selected name: Baiduc, Rachael Rebecca
# Extracted name from listing: Bailey, Dominic
# Selected name: Bailey, Dominic
# Extracted name from listing: Bailey, Karen
# Selected name: Bailey, Karen
# Extracted name from listing: Bailey Mollborn, Stefanie Faun
# Selected name: Bailey Mollborn, Stefanie Faun
# Extracted name from listing: Baird, Vanessa Anne
# Selected name: Baird, Vanessa Anne
# Extracted name from listing: Baker, Andrew B.
# Error fetching https://experts.colorado.edu/display/fisid_144377: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_144377
# Extracted name from listing: Baker, Daniel N.
# Selected name: Baker, Daniel N.
# Extracted name from listing: Baker, Kyri A.
# Selected name: Baker, Kyri A.
# Extracted name from listing: Balaji, Rajagopalan
# Selected name: Balaji, Rajagopalan
# Extracted name from listing: Balch, Jennifer Kakareka
# Selected name: Balch, Jennifer Kakareka
# Extracted name from listing: Balkin, David B.
# Selected name: Balkin, David B.
# Extracted name from listing: Ballantine, John T. Jr.
# Selected name: Ballantine, John T. Jr.
# Extracted name from listing: Bally, John
# Selected name: Bally, John
# Extracted name from listing: Bamforth, Douglas
# Selected name: Bamforth, Douglas
# Extracted name from listing: Ban, Chunmei
# Selected name: Ban, Chunmei
# Extracted name from listing: Banich, Marie
# Selected name: Banich, Marie
# Extracted name from listing: Banks, Cynthia
# Error fetching https://experts.colorado.edu/display/fisid_158245: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_158245
# Extracted name from listing: Baratta, Michael V.
# Selected name: Baratta, Michael V.
# Extracted name from listing: Barger, Nichole Nannette
# Error fetching https://experts.colorado.edu/display/fisid_131398: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_131398
# Extracted name from listing: Barham, Tania C.J.
# Selected name: Barham, Tania C.J.
# Extracted name from listing: Barker, Lecia Jane
# Selected name: Barker, Lecia Jane
# Extracted name from listing: Barkin, Sarah
# Selected name: Barkin, Sarah
# Extracted name from listing: Barlow, Lisa K.
# Selected name: Barlow, Lisa K.
# Extracted name from listing: Barlow, Melinda B.
# Selected name: Barlow, Melinda B.
# Extracted name from listing: Barnard, Holly Rene
# Selected name: Barnard, Holly Rene
# Extracted name from listing: Barnes, Frank S.
# Selected name: Barnes, Frank S.
# Extracted name from listing: Barnett, Michael T.
# Selected name: Barnett, Michael T.
# Extracted name from listing: Barrett, Bridget
# Selected name: Barrett, Bridget
# Extracted name from listing: Bartels, Justin P.
# Selected name: Bartels, Justin P.
# Extracted name from listing: Barthelat, Francois
# Selected name: Barthelat, Francois
# Extracted name from listing: Barton, Taylor Wallis
# Selected name: Barton, Taylor Wallis
# Extracted name from listing: Basey, John M.
# Selected name: Basey, John M.
# Extracted name from listing: Bashore, Kate
# Selected name: Bashore, Kate
# Extracted name from listing: Batey, Robert T.
# Selected name: Batey, Robert T.
# Extracted name from listing: Bauer, Amy
# Selected name: Bauer, Amy
# Extracted name from listing: Bay, R. Kōnane
# Selected name: Bay, R. Kōnane
# Extracted name from listing: Bayard de Volo, Lorraine M.
# Selected name: Bayard de Volo, Lorraine M.
# Extracted name from listing: Beale, Paul D.
# Selected name: Beale, Paul D.
# Extracted name from listing: Beard, Steven
# Selected name: Beard, Steven Matthew
# Extracted name from listing: Beaudry, Agnès
# Selected name: Beaudry, Agnes
# Extracted name from listing: Bebernes, Jerrold
# Selected name: Bebernes, Jerrold
# Extracted name from listing: Becher, Anne Helen
# Selected name: Becher, Anne Helen
# Extracted name from listing: Becker, Andreas
# Selected name: Becker, Andreas
# Extracted name from listing: Becker, Stephen R.
# Selected name: Becker, Stephen R.
# Extracted name from listing: Beechy, Tiffany R.
# Selected name: Beechy, Tiffany R.
# Extracted name from listing: Beer, Francis A.
# Selected name: Beer, Francis A.
# Extracted name from listing: Begelman, Mitchell C.
# Selected name: Begelman, Mitchell C.
# Extracted name from listing: Bei, Xiaoshu
# Selected name: Bei, Sarah Xiaoshu
# Extracted name from listing: Bekoff, Anne
# Selected name: Bekoff, Anne
# Extracted name from listing: Belknap, Joanne Elizabeth
# Selected name: Belknap, Joanne Elizabeth
# Extracted name from listing: Benhalim, Rabea
# Selected name: Benhalim, Rabea
# Extracted name from listing: Benim, W. Robert
# Selected name: Benim, W. Robert
# Extracted name from listing: Bennett, Douglas P.
# Selected name: Bennett, Douglas P.
# Extracted name from listing: Bentley, Francoise Judith Benay
# Selected name: Bentley, Francoise Judith Benay
# Extracted name from listing: Bercovitz, Janet
# Selected name: Bercovitz, Janet
# Extracted name from listing: Berg, Margaret H.
# Selected name: Berg, Margaret H.
# Extracted name from listing: Bergen, Lori Ann
# Selected name: Bergen, Lori Ann
# Extracted name from listing: Berggreen, Shu-Ling Chen
# Selected name: Berggreen, Shu-Ling Chen
# Extracted name from listing: Bergner, Bruce Alan
# Selected name: Bergner, Bruce Alan
# Extracted name from listing: Bernstein, Asaf
# Selected name: Bernstein, Asaf
# Extracted name from listing: Bernstein, Robin Miriam
# Selected name: Bernstein, Robin Miriam
# Extracted name from listing: Bernthal, John Bradley
# Selected name: Bernthal, John Bradley
# Extracted name from listing: Berry, Joseph
# Selected name: Berry, Joseph J.
# Extracted name from listing: Betterton, Meredith D.
# Selected name: Betterton, Meredith D.
# Extracted name from listing: Beylkin, Gregory
# Selected name: Beylkin, Gregory
# Extracted name from listing: Bhagat, Sanjai
# Selected name: Bhagat, Sanjai
# Extracted name from listing: Bhat, Yermal Sujeet
# Selected name: Bhat, Yermal Sujeet
# Extracted name from listing: Bhatia, Alpna
# Selected name: Bhatia, Alpna
# Extracted name from listing: Bickers, Kenneth Norman
# Selected name: Bickers, Kenneth Norman
# Extracted name from listing: Bickman, Martin
# Selected name: Bickman, Martin
# Extracted name from listing: Bidwell, Cinnamon
# Selected name: Bidwell, L. Cinnamon
# Extracted name from listing: Biegelsen, Casey
# Error fetching https://experts.colorado.edu/display/fisid_166072: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_166072
# Extracted name from listing: Bielefeldt, Angela R.
# Selected name: Bielefeldt, Angela R.
# Extracted name from listing: Bierbaum, Veronica
# Selected name: Bierbaum, Veronica  M
# Extracted name from listing: Biernacki, Loriliai
# Selected name: Biernacki, Loriliai
# Extracted name from listing: Biggs, Betsey
# Selected name: Biggs, Betsey
# Extracted name from listing: Bilinski, Teresa
# Selected name: Bilinski, Teresa
# Extracted name from listing: Billica, Nancy
# Selected name: Billica, Nancy
# Extracted name from listing: Billings, Stephen B.
# Selected name: Billings, Stephen B.
# Extracted name from listing: Bird-Arvidsson, Jennifer
# Selected name: Bird-Arvidsson, Jennifer
# Extracted name from listing: Bjerke, Maureen Ann
# Selected name: Bjerke, Maureen Ann
# Extracted name from listing: Black, August
# Selected name: Black, August
# Extracted name from listing: Black, John
# Selected name: Black, John
# Extracted name from listing: Blacklock, Jenifer L.
# Selected name: Blacklock, Jenifer L.
# Extracted name from listing: Blair, Irene
# Selected name: Blair, Irene V
# Extracted name from listing: Blanken, Peter David
# Selected name: Blanken, Peter David
# Extracted name from listing: Bloom, Frederic M.
# Selected name: Bloom, Frederic M.
# Extracted name from listing: Bloomfield, Elisabeth Marie Arnould
# Selected name: Arnould-Bloomfield, Elisabeth Marie
# Extracted name from listing: Blum, Arielle Melissa
# Selected name: Blum, Arielle Melissa
# Extracted name from listing: Blum, Lauren W.
# Selected name: Blum, Lauren W.
# Extracted name from listing: Blumenthal, Thomas
# Selected name: Blumenthal, Thomas
# Extracted name from listing: Boardman, Alison Gould
# Selected name: Boardman, Alison Gould
# Extracted name from listing: Boardman, Jason D.
# Selected name: Boardman, Jason D.
# Extracted name from listing: Bock, Carl L.E.
# Selected name: Bock, Carl L.E.
# Extracted name from listing: Bock, Jane H.
# Selected name: Bock, Jane H.
# Extracted name from listing: Bogatin, Eric
# Selected name: Bogatin, Eric
# Extracted name from listing: Bohn, John
# Selected name: Bohn, John
# Extracted name from listing: Boileau, Martin
# Selected name: Boileau, Martin
# Extracted name from listing: Bolhari, Azadeh
# Selected name: Bolhari, Azadeh
# Extracted name from listing: Bolton, Daniel Ryan
# Selected name: Bolton, Daniel Ryan
# Extracted name from listing: Bone, Jennifer Emerling
# Selected name: Bone, Jennifer Emerling
# Extracted name from listing: Boninger, Faith Gleicher
# Selected name: Boninger, Faith Gleicher
# Extracted name from listing: Bonjack, Stephanie Marie
# Selected name: Bonjack, Stephanie Marie
# Extracted name from listing: Boonin, David
# Selected name: Boonin, David
# Extracted name from listing: Boord, Daniel Olin
# Selected name: Boord, Daniel Olin
# Extracted name from listing: Borden, Mark A.
# Selected name: Borden, Mark A.
# Extracted name from listing: Boromisza-Habashi, David
# Selected name: Boromisza-Habashi, David
# Extracted name from listing: Bortz, David Matthew
# Selected name: Bortz, David Matthew
# Extracted name from listing: Bosanac, Natasha
# Selected name: Bosanac, Natasha
# Extracted name from listing: Boss, Russel Wayne
# Error fetching https://experts.colorado.edu/display/fisid_105260: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_105260
# Extracted name from listing: Boswell, Robert E.
# Selected name: Boswell, Robert E.
# Extracted name from listing: Bottan, Daria
# Error fetching https://experts.colorado.edu/display/fisid_168423: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_168423
# Extracted name from listing: Bottenus, Nick
# Selected name: Bottenus, Nick
# Extracted name from listing: Boulding, Carew Elizabeth
# Selected name: Boulding, Carew Elizabeth
# Extracted name from listing: Bouwman, Jordy
# Selected name: Bouwman, Jordy
# Extracted name from listing: Bowman, Christopher N.
# Selected name: Bowman, Christopher N.
# Extracted name from listing: Bowman, William D.
# Selected name: Bowman, William D.
# Extracted name from listing: Boyd, Iain
# Selected name: Boyd, Iain Douglas
# Extracted name from listing: Boyd, Samuel L.
# Selected name: Boyd, Samuel L.
# Extracted name from listing: Boyko, Marie
# Selected name: Boyko, Marie
# Extracted name from listing: Boykoff, Maxwell Thomas
# Selected name: Boykoff, Maxwell Thomas
# Extracted name from listing: Bozic, Christy L.
# Selected name: Bozic, Christy L.
# Extracted name from listing: Braaten, Melissa
# Selected name: Braaten, Melissa
# Extracted name from listing: Bradley, Elizabeth
# Selected name: Bradley, Elizabeth
# Extracted name from listing: Braider, Christopher
# Selected name: Braider, Christopher
# Extracted name from listing: Brain, David A.
# Selected name: Brain, David A.
# Extracted name from listing: Brandemuehl, Michael J.
# Selected name: Brandemuehl, Michael J.
# Extracted name from listing: Brasseur, James G.
# Selected name: Brasseur, James G.
# Extracted name from listing: Bredeson, Garrett
# Selected name: Bredeson, Garrett Zantow
# Extracted name from listing: Breed, Michael D.
# Selected name: Breed, Michael D.
# Extracted name from listing: Brennan, Christine
# Selected name: Brennan, Christine
# Extracted name from listing: Briggs, Derek Christian Mauthner
# Selected name: Briggs, Derek Christian Mauthner
# Extracted name from listing: Bright, Victor Mark
# Selected name: Bright, Victor Mark
# Extracted name from listing: Briscoe, Georgia K.
# Selected name: Briscoe, Georgia K.
# Extracted name from listing: Brody, James M.
# Selected name: Brody, James M.
# Extracted name from listing: Broering, Ellen
# Selected name: Broering, Ellen
# Extracted name from listing: Broersma, Leslee
# Selected name: Broersma, Leslee
# Extracted name from listing: Bronstein, Albert
# Selected name: Bronstein, Albert
# Extracted name from listing: Brooks, Cassandra
# Selected name: Brooks, Cassandra
# Extracted name from listing: Brown, Benjamin P.
# Selected name: Brown, Benjamin P.
# Extracted name from listing: Brown, Daniel
# Selected name: Brown, Daniel Gregory
# Extracted name from listing: Brown, Derek Philip
# Selected name: Brown, Derek Philip
# Extracted name from listing: Brown, Esther Lynn
# Selected name: Brown, Esther Lynn
# Extracted name from listing: Brown, Janice Carole
# Selected name: Brown, Janice Carole
# Extracted name from listing: Brown, Jed
# Selected name: Brown, Jed
# Extracted name from listing: Brown, Marilyn Ruth
# Selected name: Brown, Marilyn Ruth
# Extracted name from listing: Brown, Steven S.
# Selected name: Brown, Steven S.
# Extracted name from listing: Browne, Eleanor Carol
# Selected name: Browne, Eleanor Carol
# Extracted name from listing: Browsh, Jared Bahir
# Selected name: Browsh, Jared Bahir
# Extracted name from listing: Brubaker, Jed Richards
# Selected name: Brubaker, Jed Richards
# Extracted name from listing: Bruff, Harold
# Selected name: Bruff, Harold Hastings
# Extracted name from listing: Brumbaugh, Justin J.
# Selected name: Brumbaugh, Justin J.
# Extracted name from listing: Bruns, Carson J.
# Selected name: Bruns, Carson J.
# Extracted name from listing: Bruns, Steven M.
# Selected name: Bruns, Steven M.
# Extracted name from listing: Brunt, Vienna E
# Selected name: Brunt, Vienna E
# Extracted name from listing: Bryan, Angela
# Selected name: Bryan, Angela
# Extracted name from listing: Bryan, Joseph Henry
# Selected name: Bryan, Joseph Henry
# Extracted name from listing: Bryant, Stephanie J.
# Selected name: Bryant, Stephanie J.
# Extracted name from listing: Brylowe, Thora
# Selected name: Brylowe, Thora
# Extracted name from listing: Buchanan, Angela S.
# Selected name: Buchanan, Angela S.
# Extracted name from listing: Buchman, Thomas A.
# Selected name: Buchman, Thomas A.
# Extracted name from listing: Buchwald, Robert
# Selected name: Buchwald, Robert
# Extracted name from listing: Buffa, Andrea
# Selected name: Buffa, Andrea
# Extracted name from listing: Buffington, Robert Marshall
# Selected name: Buffington, Robert Marshall
# Extracted name from listing: Bumbaca, Frederico
# Selected name: Bumbaca, Frederico
# Extracted name from listing: Burba, Audrey
# Selected name: Burba, Audrey
# Extracted name from listing: Burdick, A. Jason
# Selected name: Burdick, A. Jason
# Extracted name from listing: Burge, Marjorie
# Selected name: Burge, Marjorie
# Extracted name from listing: Burger, Eric B.
# Selected name: Burger, Eric B.
# Extracted name from listing: Burgess, Matthew
# Error fetching https://experts.colorado.edu/display/fisid_164178: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_164178
# Extracted name from listing: Burke, Robin D.
# Selected name: Burke, Robin D.
# Extracted name from listing: Bustamante, Heidi Margarita
# Selected name: Bustamante, Heidi Margarita
# Extracted name from listing: Buttenfield, Barbara P.
# Selected name: Buttenfield, Barbara P.
# Extracted name from listing: Byrd, Sigman M.
# Selected name: Byrd, Sigman M.
# Extracted name from listing: Byrnes, William
# Selected name: Byrnes, William
# Extracted name from listing: Caballero, Carlo
# Selected name: Caballero, Carlo
# Extracted name from listing: Cadena, Brian C.
# Selected name: Cadena, Brian C.
# Extracted name from listing: Cai, Xiao-Chuan
# Selected name: Cai, Xiao-Chuan
# Extracted name from listing: Cain, Andrew J.
# Selected name: Cain, Andrew J.
# Extracted name from listing: Caine, T. Nelson
# Selected name: Caine, Thomas Nelson
# Extracted name from listing: Calabrese, Andrew
# Selected name: Calabrese, Andrew
# Extracted name from listing: Calder, Jeremy
# Selected name: Calder, Jeremy
# Extracted name from listing: Calkins, Michael Andrew
# Selected name: Calkins, Michael Andrew
# Extracted name from listing: Callier, Reina
# Selected name: Callier, Reina E
# Extracted name from listing: Calve, Sarah
# Selected name: Calve, Sarah
# Extracted name from listing: Cameron, Jeffrey C.
# Error fetching https://experts.colorado.edu/display/fisid_156473: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_156473
# Extracted name from listing: Campbell, Kimberly D.
# Selected name: Campbell, Kimberly D.
# Extracted name from listing: Campeau, Serge
# Selected name: Campeau, Serge
# Extracted name from listing: Campos, Paul F.
# Selected name: Campos, Paul F.
# Extracted name from listing: Cantrell, Deborah Jane
# Selected name: Cantrell, Deborah Jane
# Extracted name from listing: Cantrell, Melissa
# Selected name: Cantrell, Melissa Hart
# Extracted name from listing: Cao, Gang
# Selected name: Cao, Gang
# Extracted name from listing: Cao, Guofeng
# Selected name: Cao, Guofeng
# Extracted name from listing: Carballo, Jeronimo Rafael
# Selected name: Carballo, Jeronimo Rafael
# Extracted name from listing: Carbone, Christopher
# Selected name: Carbone, Christopher
# Extracted name from listing: Carey, Frederick
# Selected name: Carey, Frederick C.
# Extracted name from listing: Carlos, Ann M.
# Selected name: Carlos, Ann M.
# Extracted name from listing: Carpenter, J. Harrison
# Selected name: Carpenter, J. Harrison
# Extracted name from listing: Carpenter, Kristen Ann
# Selected name: Carpenter, Kristen Ann
# Extracted name from listing: Carr, Julia Alice
# Selected name: Carr, Julie Alice
# Extracted name from listing: Carrico, Amanda R.
# Selected name: Carrico, Amanda R.
# Extracted name from listing: Carroll, Clinton R.
# Selected name: Carroll, Clinton R.
# Extracted name from listing: Carruth, Christopher
# Selected name: Carruth, Christopher M
# Extracted name from listing: Carson, Visda
# Selected name: Carson, Visda
# Extracted name from listing: Carter Carston, Ronald McKell
# Selected name: Carter Carston, Ronald McKell
# Extracted name from listing: Carthy, Nicholas R.
# Selected name: Carthy, Nicholas R.
# Extracted name from listing: Cartun, Ashley
# Selected name: Cartun, Ashley
# Extracted name from listing: Caruthers, Marvin H.
# Selected name: Caruthers, Marvin H.
# Extracted name from listing: Cary, John R.
# Selected name: Cary, John R.
# Extracted name from listing: Casagrand, Janet L.
# Selected name: Casagrand, Janet L.
# Extracted name from listing: Casalaina-Martin, Sebastian Ben
# Selected name: Casalaina-Martin, Sebastian Ben
# Extracted name from listing: Cash, Webster C. Jr.
# Selected name: Cash, Webster C. Jr.
# Extracted name from listing: Cassano, John J.
# Selected name: Cassano, John J.
# Extracted name from listing: Castro, Francisco
# Selected name: Castro, Francisco
# Extracted name from listing: Catlos, Brian Aivars
# Selected name: Catlos, Brian Aivars
# Extracted name from listing: Cech, Thomas R.
# Selected name: Cech, Thomas R.
# Extracted name from listing: Celoza, Amelia
# Selected name: Celoza, Amelia
# Extracted name from listing: Cha, Jennifer N.
# Selected name: Cha, Jennifer N.
# Extracted name from listing: Chamberlin, H. Scott
# Selected name: Chamberlin, H. Scott
# Extracted name from listing: Chambers, Lee Virginia
# Selected name: Chambers, Lee Virginia
# Extracted name from listing: Chang, Bor-Yuh Evan
# Selected name: Chang, Bor-Yuh Evan
# Extracted name from listing: Chang, Philip C.
# Selected name: Chang, Philip C.
# Extracted name from listing: Chang, Silva
# Selected name: Chang, Silva
# Extracted name from listing: Chapin, Violeta Raquel
# Selected name: Chapin, Violeta Raquel
# Extracted name from listing: Chari, Mukund
# Selected name: Chari, Mukund
# Extracted name from listing: Charlet, Caitlin
# Selected name: Charlet, Caitlin
# Extracted name from listing: Chaudhary, Sumeet
# Selected name: Chaudhary, Sumeet
# Extracted name from listing: Chawla, Louise
# Selected name: Chawla, Louise
# Extracted name from listing: Chellis, Matthew Wren
# Selected name: Chellis, Matthew Wren
# Extracted name from listing: Chen, Lijun
# Selected name: Chen, Lijun
# Extracted name from listing: Chen, Xudong
# Selected name: Chen, Xudong
# Extracted name from listing: Chen, Yongmin
# Selected name: Chen, Yongmin
# Extracted name from listing: Chernus, Ira R.
# Selected name: Chernus, Ira R.
# Extracted name from listing: Chester, Lucy P.
# Selected name: Chester, Lucy P.
# Extracted name from listing: Chin, Karen
# Selected name: Chin, Karen
# Extracted name from listing: Chong, Albert
# Selected name: Chong, Albert  V.
# Extracted name from listing: Christoff, Lorna Colleen
# Selected name: Christoff, Lorna Colleen
# Extracted name from listing: Chu, Xinzhao
# Selected name: Chu, Xinzhao
# Extracted name from listing: Chuang, Angie
# Selected name: Chuang, Angie
# Extracted name from listing: Ciarlo, David Michael
# Selected name: Ciarlo, David Michael
# Extracted name from listing: Ciota, Rebecca
# Selected name: Ciota, Rebecca
# Extracted name from listing: Ciplet, David
# Selected name: Ciplet, David
# Extracted name from listing: Clark, Alisha
# Selected name: Clark, Alisha Nicole
# Extracted name from listing: Clark, Noel A.
# Selected name: Clark, Noel A.
# Extracted name from listing: Clark, Patrick Ryan
# Selected name: Clark, Patrick Ryan
# Extracted name from listing: Clark, Torin K.
# Selected name: Clark, Torin K.
# Extracted name from listing: Clauset, Aaron
# Selected name: Clauset, Aaron
# Extracted name from listing: Cleland, Carol
# Selected name: Cleland, Carol
# Extracted name from listing: Clelland, Jeanne Nielsen
# Selected name: Clelland, Jeanne Nielsen
# Extracted name from listing: Clough, David Edwards
# Selected name: Clough, David Edwards
# Extracted name from listing: Cogswell, Carol
# Selected name: Cogswell, Carol
# Extracted name from listing: Cohen, Brianne Caitlin
# Selected name: Cohen, Brianne Caitlin
# Extracted name from listing: Coleman, Bertram E.
# Error fetching https://experts.colorado.edu/display/fisid_103065: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_103065
# Extracted name from listing: Colley, Dawn
# Selected name: Colley, Dawn F
# Extracted name from listing: Collins, Lauren
# Selected name: Collins, Lauren Katherine
# Extracted name from listing: Collins, Richard B.
# Selected name: Collins, Richard B.
# Extracted name from listing: Colunga, Eliana
# Selected name: Colunga, Eliana
# Extracted name from listing: Combes, Josh
# Error fetching https://experts.colorado.edu/display/fisid_166284: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_166284
# Extracted name from listing: Comerford, Julia M.
# Selected name: Comerford, Julia M.
# Extracted name from listing: Comstock, Cathy
# Error fetching https://experts.colorado.edu/display/fisid_101895: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_101895
# Extracted name from listing: Contreras, Ana
# Selected name: Contreras, Ana
# Extracted name from listing: Conway, Laura
# Selected name: Conway, Laura Rachel
# Extracted name from listing: Conzelman, Caroline S.
# Selected name: Conzelman, Caroline S.
# Extracted name from listing: Cook, Sherri M.
# Selected name: Cook, Sherri M.
# Extracted name from listing: Cook-Martin, David
# Selected name: Cook-Martín, David
# Extracted name from listing: Cookson, John Anthony
# Selected name: Cookson, John Anthony
# Extracted name from listing: Cool, Alison Collier
# Selected name: Cool, Alison Collier
# Extracted name from listing: Coombs Esmail, Eric
# Selected name: Coombs Esmail, Eric David
# Extracted name from listing: Cooper, Peter W.
# Selected name: Cooper, Peter W.
# Extracted name from listing: Cooperstock, Andrew B.
# Selected name: Cooperstock, Andrew B.
# Extracted name from listing: Copley, Shelley
# Selected name: Copley, Shelley
# Extracted name from listing: Corcoran, Jem
# Selected name: Corcoran, Jem
# Extracted name from listing: Cordes, Dietmar
# Selected name: Cordes, Dietmar
# Extracted name from listing: Cordova, James M.
# Selected name: Cordova, James M.
# Extracted name from listing: Cornell, Eric
# Selected name: Cornell, Eric
# Extracted name from listing: Corotis, Ross B.
# Selected name: Corotis, Ross B.
# Extracted name from listing: Corradini, Luca
# Selected name: Corradini, Luca
# Extracted name from listing: Correll, Joshua
# Selected name: Correll, Joshua
# Extracted name from listing: Correll, Nikolaus J.
# Selected name: Correll, Nikolaus J.
# Extracted name from listing: Cortez, Arturo
# Error fetching https://experts.colorado.edu/display/fisid_165977: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_165977
# Extracted name from listing: Corwin, Lisa A.
# Selected name: Corwin, Lisa Auchincloss
# Extracted name from listing: Costain, Anne N.
# Selected name: Costain, Anne N.
# Extracted name from listing: Couture, Juliann Elizabeth
# Selected name: Couture, Juliann Elizabeth
# Extracted name from listing: Cowell, James Andrew
# Selected name: Cowell, James Andrew
# Extracted name from listing: Cox, Jeffrey N.
# Selected name: Cox, Jeffrey N.
# Extracted name from listing: Cox, Murray William
# Selected name: Cox, Murray William
# Extracted name from listing: Craighead, H Daniel
# Error fetching https://experts.colorado.edu/display/fisid_159477: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_159477
# Extracted name from listing: Cranmer, Steven
# Selected name: Cranmer, Steven  R.
# Extracted name from listing: Craven, Priscilla
# Selected name: Craven, Priscilla
# Extracted name from listing: Crawley, Adam
# Selected name: Crawley, Stephen Adam
# Extracted name from listing: Cremaschi, Alejandro M.
# Selected name: Cremaschi, Alejandro M.
# Extracted name from listing: Crichlow, Gregory
# Selected name: Crichlow, Gregory John
# Extracted name from listing: Crimaldi, John P.
# Selected name: Crimaldi, John P.
# Extracted name from listing: Crofton, Karen
# Selected name: Crofton, Karen Marie
# Extracted name from listing: Cropanzano, Russell Salvador
# Selected name: Cropanzano, Russell Salvador
# Extracted name from listing: Crow, Carolyn Alicia
# Selected name: Crow, Carolyn Alicia
# Extracted name from listing: Cruz, Joelle
# Selected name: Cruz, Joelle M
# Extracted name from listing: Cui, Longji
# Selected name: Cui, Longji
# Extracted name from listing: Cuk, Tanja
# Selected name: Cuk, Tanja
# Extracted name from listing: Cumalat, John P.
# Selected name: Cumalat, John P.
# Extracted name from listing: Cummings, Andrew
# Selected name: Cummings, Andrew
# Extracted name from listing: Cundiff, Milford F.
# Selected name: Cundiff, Milford F.
# Extracted name from listing: Cunningham, Cory
# Selected name: Cunningham, Cory Brooke
# Extracted name from listing: Curran, Timothy
# Selected name: Curran, Timothy
# Extracted name from listing: Curry, James H.
# Selected name: Curry, James (Jim) H
# Extracted name from listing: Curtis, Ryan
# Selected name: Curtis, Ryan Dean
# Extracted name from listing: Czubak, Magdalena
# Selected name: Czubak, Magdalena
# Extracted name from listing: D'Mello, Sidney
# Selected name: D'Mello, Sidney
# Extracted name from listing: Dabove, Juan Pablo
# Selected name: Dabove, Juan Pablo
# Extracted name from listing: Daily, John W.
# Selected name: Daily, John W.
# Extracted name from listing: Dall'Anese, Emiliano
# Error fetching https://experts.colorado.edu/display/fisid_158949: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_158949
# Extracted name from listing: Dalton, Shamika
# Selected name: Dalton, Shamika
# Extracted name from listing: Damrauer, Niels Harley
# Selected name: Damrauer, Niels Harley
# Extracted name from listing: Darling, Jeremiah K.
# Selected name: Darling, Jeremiah K.
# Extracted name from listing: Dashti, Shideh
# Selected name: Dashti, Shideh
# Extracted name from listing: Daugherty, Paul J.
# Selected name: Daugherty, Paul J.
# Extracted name from listing: Dauverd, Celine
# Selected name: Dauverd, Celine
# Extracted name from listing: David, Emmanuel A.
# Selected name: David, Emmanuel A.
# Extracted name from listing: Davies, Kendi F.
# Selected name: Davies, Kendi F.
# Extracted name from listing: Davies, Shaun William
# Selected name: Davies, Shaun William
# Extracted name from listing: Davis, John S.
# Selected name: Davis, John S.
# Extracted name from listing: Davis, Robert H.
# Selected name: Davis, Robert H.
# Extracted name from listing: Day, Heidi E.W.
# Selected name: Day, Heidi E.W.
# Extracted name from listing: de Alwis, Lisa
# Selected name: de Alwis, Lisa
# Extracted name from listing: De Alwis, Senarath P.
# Selected name: De Alwis, Senarath P.
# Extracted name from listing: De Bartolome, Charles A.M.
# Selected name: De Bartolome, Charles A.M.
# Extracted name from listing: de Gouw, Joost
# Selected name: de Gouw, Joost
# Extracted name from listing: de Lange, Marcel
# Selected name: de Lange, Marcel
# Extracted name from listing: de Stecher, Annette W.
# Selected name: de Stecher, Annette W.
# Extracted name from listing: Deagman Simonetta, Rachael Nicole
# Selected name: Deagman Simonetta, Rachael Nicole
# Extracted name from listing: Deca, Jan
# Selected name: Deca, Jan
# Extracted name from listing: DeDecker, Brian S.
# Selected name: DeDecker, Brian S.
# Extracted name from listing: Dee, Laura
# Selected name: Dee, Laura
# Extracted name from listing: DeForest, Denise
# Selected name: Deforest, Denise
# Extracted name from listing: Degrand, Thomas A.
# Selected name: Degrand, Thomas A.
# Extracted name from listing: deGrazia, Janet
# Selected name: deGrazia, Janet
# Extracted name from listing: DeLuca, Laura M.
# Selected name: DeLuca, Laura M.
# Extracted name from listing: Demarest, Heather
# Selected name: Demarest, Heather
# Extracted name from listing: Demmig-Adams, Barbara
# Selected name: Demmig-Adams, Barbara
# Extracted name from listing: Derderyan, Svet
# Selected name: Derderyan, Svet
# Extracted name from listing: Desan, Mathieu
# Selected name: Desan, Mathieu
# Extracted name from listing: Desautels-Stein, Justin Jacob
# Selected name: Desautels-Stein, Justin Jacob
# Extracted name from listing: DeShell, Jeffrey
# Selected name: Deshell, Jeffrey
# Extracted name from listing: DeSouza, Christopher A.
# Selected name: DeSouza, Christopher A.
# Extracted name from listing: Dessau, Daniel S.
# Selected name: Dessau, Daniel S.
# Extracted name from listing: Detweiler, Corrella Scott
# Selected name: Detweiler, Corrella Scott
# Extracted name from listing: Devendorf, Laura
# Selected name: Devendorf, Laura Kay
# Extracted name from listing: DeWolfe, Oliver M.
# Selected name: DeWolfe, Oliver M.
# Extracted name from listing: Dexter, Jason
# Selected name: Dexter, Jason A
# Extracted name from listing: Dickey, Kimberly
# Selected name: Dickey, Kimberly
# Extracted name from listing: Dickson, Rebecca
# Selected name: Dickson, Rebecca
# Extracted name from listing: Diddams, Scott A.
# Selected name: Diddams, Scott A.
# Extracted name from listing: Diduch, Paul Jordan
# Selected name: Diduch, Paul Jordan
# Extracted name from listing: Dike, Steven
# Selected name: Dike, Steven
# Extracted name from listing: Dimidjian, Sona
# Selected name: Dimidjian, Sona
# Extracted name from listing: Dincao, Jose Paulo
# Error fetching https://experts.colorado.edu/display/fisid_143731: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_143731
# Extracted name from listing: Ding, Xiaoyun
# Selected name: Ding, Xiaoyun
# Extracted name from listing: Ding, Yifu
# Selected name: Ding, Yifu
# Extracted name from listing: DiStefano, Philip
# Selected name: DiStefano, Philip
# Extracted name from listing: Dmukhovskaya, Marina
# Selected name: Dmukhovskaya, Marina
# Extracted name from listing: Do, Ellen Yi-Luen
# Error fetching https://experts.colorado.edu/display/fisid_159925 : 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_159925%20
# Extracted name from listing: Doak, Daniel Forest
# Selected name: Doak, Daniel Forest
# Extracted name from listing: Dockendorf, Matthew Paul
# Selected name: Dockendorf, Matthew Paul
# Extracted name from listing: Dolan, Natalia Sue
# Selected name: Tingle Dolan, Natalia
# Extracted name from listing: Dommermuth, Emily
# Selected name: Dommermuth, Emily
# Extracted name from listing: Donaldson, Zoe
# Selected name: Donaldson, Zoe Rebecca
# Extracted name from listing: Donato, Ruben
# Selected name: Donato, Ruben
# Extracted name from listing: Donavan, Janet Lynn
# Selected name: Donavan, Janet Lynn
# Extracted name from listing: Donchez, Robert M.
# Selected name: Donchez, Robert M.
# Extracted name from listing: Donohew, Zachary
# Selected name: Donohew, Zachary
# Extracted name from listing: Doostan, Alireza
# Selected name: Doostan, Alireza
# Extracted name from listing: Doran, Kevin
# Selected name: Doran, Kevin
# Extracted name from listing: Doty, Dawn
# Selected name: Doty, Dawn
# Extracted name from listing: Dougherty, Anne Margaret
# Selected name: Dougherty, Anne Margaret
# Extracted name from listing: Douglas, Marcia B.
# Selected name: Douglas, Marcia B.
# Extracted name from listing: Douglass, Scot Ray
# Selected name: Douglass, Scot Ray
# Extracted name from listing: Dowell, Robin D.
# Selected name: Dowell, Robin D.
# Extracted name from listing: Downey, Liam C.
# Selected name: Downey, Liam C.
# Extracted name from listing: Doyle, Damian P.
# Selected name: Doyle, Damian P.
# Extracted name from listing: Drake, David Francis
# Selected name: Drake, David Francis
# Extracted name from listing: Drumheller, John E.
# Selected name: Drumheller, John E.
# Extracted name from listing: Drybread, Kristen
# Selected name: Drybread, Kristen
# Extracted name from listing: Dubson, Michael A.
# Selected name: Dubson, Michael A.
# Extracted name from listing: Dufour, Darna L.
# Selected name: Dufour, Darna L.
# Extracted name from listing: Dukic, Vanja
# Selected name: Dukic, Vanja
# Extracted name from listing: Dukovic, Gordana
# Selected name: Dukovic, Gordana
# Extracted name from listing: Dulock, Michael J.
# Selected name: Dulock, Michael J.
# Extracted name from listing: Dunn, James M.
# Selected name: Dunn, James M.
# Extracted name from listing: Dupré, Jill Van Matre
# Selected name: Dupré, Jill Van Matre
# Extracted name from listing: Duren, Ron G. Jr.
# Selected name: Duren, Ron G, Jr.
# Extracted name from listing: Dusinberre, Edward
# Selected name: Dusinberre, Edward
# Extracted name from listing: Dusinberre, Elspeth Rogers Mcin
# Selected name: Dusinberre, Elspeth Rogers Mcin
# Extracted name from listing: Dutro, Elizabeth
# Selected name: Dutro, Elizabeth
# Extracted name from listing: Dyrness, Andrea E.
# Selected name: Dyrness, Andrea E.
# Extracted name from listing: Eargle, David
# Selected name: Eargle, David
# Extracted name from listing: Eaves, Joel David
# Selected name: Eaves, Joel David
# Extracted name from listing: Eberle, Jaelyn J.
# Selected name: Eberle, Jaelyn J.
# Extracted name from listing: Echchaibi, Nabil
# Selected name: Echchaibi, Nabil
# Extracted name from listing: Eckert, Erika L.
# Selected name: Eckert, Erika L.
# Extracted name from listing: Edwards, Emily
# Selected name: Edwards, Emily
# Extracted name from listing: Eggert, Katherine
# Selected name: Eggert, Katherine
# Extracted name from listing: Ehly, Jeremy G.
# Selected name: Ehly, Jeremy G.
# Extracted name from listing: Ehringer, Marissa A.
# Selected name: Ehringer, Marissa A.
# Extracted name from listing: Eichmann-Kalwara, Nickoal
# Selected name: Eichmann-Kalwara, Nickoal
# Extracted name from listing: Ellingson, Erica
# Selected name: Ellingson, Erica
# Extracted name from listing: Elliott, Jacqueline Michelle
# Selected name: Elliott, Jacqueline Michelle
# Extracted name from listing: Elliott, Peter D.
# Selected name: Elliott, Peter D.
# Extracted name from listing: Ellis, Jay
# Selected name: Ellis, Jay
# Extracted name from listing: Ellsworth, Michelle
# Selected name: Ellsworth, Michelle
# Extracted name from listing: Elmore, Peter Michael
# Selected name: Elmore, Peter Michael
# Extracted name from listing: Emerson, Lori Ann
# Selected name: Emerson, Lori Ann
# Extracted name from listing: Emery, Nancy Christine
# Selected name: Emery, Nancy Christine
# Extracted name from listing: Emery, William J.
# Selected name: Emery, William J.
# Extracted name from listing: Engel, Barbara A.
# Selected name: Engel, Barbara A.
# Extracted name from listing: Engel, Mimi
# Selected name: Engel, Mimi
# Extracted name from listing: England, Margaret Ann
# Selected name: England, Margaret Ann
# Extracted name from listing: Englander, Janos
# Selected name: Engländer, János
# Extracted name from listing: English, Michael D.
# Selected name: English, Michael D.
# Extracted name from listing: Enoka, Roger M.
# Selected name: Enoka, Roger M.
# Extracted name from listing: Ergun, Robert E.
# Selected name: Ergun, Robert E.
# Extracted name from listing: Erhard, Paul M.
# Selected name: Erhard, Paul M.
# Extracted name from listing: Erickson, Robert W.
# Selected name: Erickson, Robert W.
# Extracted name from listing: Ertimur, Yonca
# Selected name: Ertimur, Yonca
# Extracted name from listing: Escamilla, Kathy M.
# Selected name: Escamilla, Kathy M.
# Extracted name from listing: Espelie, Erin Marie
# Selected name: Espelie, Erin Marie
# Extracted name from listing: Espinosa, Joaquin Maximiliano
# Selected name: Espinosa, Joaquin Maximiliano
# Extracted name from listing: Esposito, Larry Wayne
# Selected name: Esposito, Larry Wayne
# Extracted name from listing: Evans, John A.
# Selected name: Evans, John A.
# Extracted name from listing: Evans, Luke M.
# Selected name: Evans, Luke M.
# Extracted name from listing: Evers, Neal
# Selected name: Evers, Neal
# Extracted name from listing: Falconer, John L.
# Selected name: Falconer, John L.
# Extracted name from listing: Falke, Joseph J.
# Selected name: Falke, Joseph J.
# Extracted name from listing: Fantalis, Maryanne
# Selected name: Fantalis, Maryanne
# Extracted name from listing: Farago, Claire Joan
# Selected name: Farago, Claire Joan
# Extracted name from listing: Farkas Roszell, Agnes
# Selected name: Farkas Roszell, Agnes
# Extracted name from listing: Farmer, G. Lang
# Selected name: Farmer, G. Lang
# Extracted name from listing: Farmer, James Clark
# Selected name: Farmer, James Clark
# Extracted name from listing: Farnsworth, John A.
# Selected name: Farnsworth, John A.
# Extracted name from listing: Farr, Elizabeth G.
# Selected name: Farr, Elizabeth G.
# Extracted name from listing: Farrell, Caitlin
# Selected name: Farrell, Caitlin Christine
# Extracted name from listing: Farrelly, Raichle
# Selected name: Farrelly, Raichle
# Extracted name from listing: Farsi, Carla Emilia
# Selected name: Farsi, Parvati Carla  Emilia
# Extracted name from listing: Feeler, Jordan
# Selected name: Feeler, Jordan
# Extracted name from listing: Fejer, Andras
# Selected name: Fejer, Andras
# Extracted name from listing: Felderman, Melissa
# Selected name: Felderman, Melissa H
# Extracted name from listing: Feldman, Andrea
# Selected name: Feldman, Andrea
# Extracted name from listing: Felippa, Carlos A.
# Selected name: Felippa, Carlos A.
# Extracted name from listing: Fenn, Elizabeth Anne
# Selected name: Fenn, Elizabeth Anne
# Extracted name from listing: Ferguson, Michaele L.
# Selected name: Ferguson, Michaele L.
# Extracted name from listing: Ferguson, Virginia L.
# Selected name: Ferguson, Virginia Lea
# Extracted name from listing: Fernbach, Philip M.
# Selected name: Fernbach, Philip M.
# Extracted name from listing: Ferrell, Tracy L.
# Selected name: Ferrell, Tracy L.
# Extracted name from listing: Ferris, Anna M.
# Selected name: Ferris, Anna M.
# Extracted name from listing: Ferris, David S.
# Selected name: Ferris, David S.
# Extracted name from listing: Ferry, Robert J.
# Selected name: Ferry, Robert J.
# Extracted name from listing: Fierer, Noah
# Selected name: Fierer, Noah
# Extracted name from listing: Fiesler, Casey Lynn
# Selected name: Fiesler, Casey Lynn
# Extracted name from listing: Fiez, Terri S.
# Selected name: Fiez, Terri S.
# Extracted name from listing: Figueroa, Nuris
# Selected name: Figueroa, Nuris
# Extracted name from listing: Fileva, Iskra
# Selected name: Fileva, Iskra
# Extracted name from listing: Filipovic, Dejan S.
# Selected name: Filipovic, Dejan S.
# Extracted name from listing: Fillman, Christy L.
# Selected name: Fillman, Christy L.
# Extracted name from listing: Finkelstein, Noah D.
# Selected name: Finkelstein, Noah D.
# Extracted name from listing: Fischer, Kate
# Selected name: Fischer, Kate
# Extracted name from listing: Fisher, Christina Marie
# Selected name: Morrin, Christina Marie
# Extracted name from listing: Fisher, Jolene
# Selected name: Fisher, Jolene
# Extracted name from listing: Fitzgerald, Jennifer L.
# Selected name: Fitzgerald, Jennifer L.
# Extracted name from listing: Fladd, Samantha G.
# Error fetching https://experts.colorado.edu/display/fisid_165651: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_165651
# Extracted name from listing: Flaxman, Samuel M.
# Selected name: Flaxman, Samuel M.
# Extracted name from listing: Fleming, Brian
# Selected name: Fleming, Brian Thomas
# Extracted name from listing: Fleshner, Monika R.
# Selected name: Fleshner, Monika R.
# Extracted name from listing: Flores, Nicholas E.
# Selected name: Flores, Nicholas E.
# Extracted name from listing: Floriano, Maureen
# Selected name: Floriano, Maureen
# Extracted name from listing: Flowers, Rebecca M.
# Selected name: Flowers, Rebecca M.
# Extracted name from listing: Fluri, Jennifer L.
# Selected name: Fluri, Jennifer L.
# Extracted name from listing: Fobes, Alexander S.
# Selected name: Fobes, Alexander S.
# Extracted name from listing: Foley, Teresa E.
# Selected name: Foley, Teresa E.
# Extracted name from listing: Fong, Judith Yem Siu
# Selected name: Fong, Judith Yem Siu
# Extracted name from listing: Forbes, Jeffrey M.
# Selected name: Forbes, Jeffrey M.
# Extracted name from listing: Ford, William T.
# Selected name: Ford, William T.
# Extracted name from listing: Fornberg, Bengt
# ...
# Selected name: Manzitto-Tripp, Erin Anne
# Extracted name from listing: Trivedi, Ashutosh
# Selected name: Trivedi, Ashutosh
# Extracted name from listing: Trnka-Amrhein, Yvona
# Selected name: Trnka-Amrhein, Yvona
# Extracted name from listing: Trower, Lizzy
# Selected name: Trower, Lizzy
# Extracted name from listing: Truelove, Yaffa Elane
# Selected name: Truelove, Yaffa Elane
# Extracted name from listing: Trujillo, Nicole
# Selected name: Trujillo, Nicole LeBoeuf
# Extracted name from listing: Truong, Le Hoang
# Selected name: Truong, Hoang Le
# Extracted name from listing: Tsai, Janet Yi-Jen
# Selected name: Tsai, Janet Yi-Jen
# Extracted name from listing: Tsai, Pei-San
# Selected name: Tsai, Pei-San
# Extracted name from listing: Tsouhlarakis, Georgianna
# Selected name: Tsouhlarakis, Georgianna
# Extracted name from listing: Tucker, Gregory E.
# Selected name: Tucker, Gregory E.
# Extracted name from listing: Tufo, Henry
# Selected name: fisid_127040
# Extracted name from listing: Turetsky, Merritt
# Selected name: Turetsky, Merritt
# Extracted name from listing: Ulmer, Keith A.
# Selected name: Ulmer, Keith A.
# Extracted name from listing: Upadhyay, Nishant
# Selected name: Upadhyay, Nishant
# Extracted name from listing: Upczak, Emilie
# Error fetching https://experts.colorado.edu/display/fisid_163326: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_163326
# Extracted name from listing: Urland, Geoffrey Raymond
# Selected name: Urland, Geoffrey Raymond
# Extracted name from listing: Urrea, Gloria
# Selected name: Urrea, Gloria
# Extracted name from listing: Uzdensky, Dmitri Anatoljevich
# Error fetching https://experts.colorado.edu/display/fisid_147430: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_147430
# Extracted name from listing: Vaida, Veronica
# Selected name: Vaida, Veronica
# Extracted name from listing: Valdovino, Luis Hector
# Selected name: Valdovino, Luis Hector
# Extracted name from listing: Valente-Quinn, Brian Dennis
# Selected name: Valente-Quinn, Brian Dennis
# Extracted name from listing: Van Blerkom, Jonathan
# Selected name: Van Blerkom, Jonathan
# Extracted name from listing: Van Boven, Leaf D.
# Selected name: Van Boven, Leaf D.
# Extracted name from listing: Van Buskirk, Allison
# Selected name: Van Buskirk, Allison
# Extracted name from listing: van de Lagemaat, Jao
# Selected name: Van de Lagemaat, Jao
# Extracted name from listing: Van Horne, Jesse
# Error fetching https://experts.colorado.edu/display/fisid_166162: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_166162
# Extracted name from listing: Van Hoye, Allan
# Selected name: Van Hoye, Allan Lyle
# Extracted name from listing: Van Nelson, Loredana Alina
# Selected name: Van Nelson, Loredana Alina
# Extracted name from listing: Van Vuuren, Sarel
# Selected name: Van Vuuren, Sarel
# Extracted name from listing: Van Wesep, Edward D.
# Selected name: Van Wesep, Edward D.
# Extracted name from listing: Van Zeghbroeck, Bart J.
# Selected name: Van Zeghbroeck, Bart J.
# Extracted name from listing: Vance, Eric
# Selected name: Vance, Eric
# Extracted name from listing: Vance, Marina E.
# Selected name: Vance, Marina (Nina) E.
# Extracted name from listing: VandenBosch, Adrienne
# Selected name: VandenBosch, Adrienne
# Extracted name from listing: Vanderbeek, Greg
# Error fetching https://experts.colorado.edu/display/fisid_159741: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_159741
# Extracted name from listing: Vanderheiden, Steven Jon
# Selected name: Vanderheiden, Steven Jon
# Extracted name from listing: Vandermarliere, Sandrine
# Selected name: Vandermarliere, Sandrine
# Extracted name from listing: Varanasi, Mahesh K.
# Selected name: Varanasi, Mahesh K.
# Extracted name from listing: Vargas, Edgar
# Selected name: Vargas Blanco, Edgar Mauricio
# Extracted name from listing: Vargo, Christopher
# Selected name: Vargo, Christopher
# Extracted name from listing: Vàsconez, Sandra L.
# Selected name: Vasconez, Sandra L.
# Extracted name from listing: Vasile, Olga
# Selected name: Vasile, Olga
# Extracted name from listing: Veblen, Thomas T.
# Selected name: Veblen, Thomas T.
# Extracted name from listing: Velte, Ashlyn
# Selected name: Velte, Ashlyn
# Extracted name from listing: Vernerey, Divya E.
# Selected name: Vernerey, Divya E.
# Extracted name from listing: Vernerey, Franck J.
# Selected name: Vernerey, Franck J.
# Extracted name from listing: Villanueva, Nicholas
# Selected name: Villanueva, Nicholas
# Extracted name from listing: Vodehnal, Carrie
# Selected name: Vodehnal, Carrie
# Extracted name from listing: Voeltz, Gia Kaarina
# Selected name: Voeltz, Gia Kaarina
# Extracted name from listing: Voida, Amy Kathryn Mitchell
# Selected name: Voida, Amy Kathryn Mitchell
# Extracted name from listing: Voida, Stephen A.
# Selected name: Voida, Stephen A.
# Extracted name from listing: Volkamer, Rainer
# Selected name: Volkamer, Rainer
# Extracted name from listing: Volpone, Sabrina D.
# Selected name: Volpone, Sabrina D.
# Extracted name from listing: von der Nuell, Tobin D.
# Selected name: von der Nuell, Tobin D.
# Extracted name from listing: Voss, James S.
# Selected name: Voss, James S.
# Extracted name from listing: Vossen, Thomas Wilhelmus
# Selected name: Vossen, Thomas Wilhelmus
# Extracted name from listing: Vriend, Nathalie Maria
# Selected name: Vriend, Nathalie Maria
# Extracted name from listing: Wadsworth, Thomas Pearson
# Selected name: Wadsworth, Thomas Pearson
# Extracted name from listing: Wagner, Kelvin
# Selected name: Wagner, Kelvin  H.
# Extracted name from listing: Wagner, Stephen R.
# Selected name: Wagner, Stephen R.
# Extracted name from listing: Walba, David M.
# Selected name: Walba, David M.
# Extracted name from listing: Walczak, Maciej Andrzej
# Selected name: Walczak, Maciej Andrzej
# Extracted name from listing: Walden, Glenda D.
# Selected name: Walden, Glenda D.
# Extracted name from listing: Walker, Melanie
# Selected name: Walker, Melanie
# Extracted name from listing: Walker, Michael Edward
# Selected name: Walker, Michael Edward
# Extracted name from listing: Walter, Douglas W.
# Selected name: Walter, Douglas Wm.
# Extracted name from listing: Walter, Martin E.
# Selected name: Walter, Martin E.
# Extracted name from listing: Wang, Clare
# Selected name: Wang, Clare
# Extracted name from listing: Wang, Mia
# Selected name: Wang, Yanyun Mia
# Extracted name from listing: Wang, Xiang
# Selected name: Wang, Xiang
# Extracted name from listing: Wang, Xinyue
# Selected name: Wang, Xinyue
# Extracted name from listing: Wang, Xu
# Selected name: Wang, Xu
# Extracted name from listing: Wang, Zhiyi
# Selected name: Wang, Zhiyi
# Extracted name from listing: Ward, Wayne Hinson
# Selected name: Ward, Wayne Hinson
# Extracted name from listing: Wartell, Rebecca
# Error fetching https://experts.colorado.edu/display/fisid_164288: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_164288
# Extracted name from listing: Waters, Brian Todd
# Selected name: Waters, Brian Todd
# Extracted name from listing: Waters, Keith John
# Selected name: Waters, Keith John
# Extracted name from listing: Watkins, Alexander Charlton
# Selected name: Watkins, Alexander Charlton
# Extracted name from listing: Watkins, Linda R.
# Selected name: Watkins, Linda R.
# Extracted name from listing: Weaver, Kay
# Selected name: Weaver, Kay
# Extracted name from listing: Weaver, Zachary Markus
# Selected name: Weaver, Zachary Markus
# Extracted name from listing: Webb, David C.
# Selected name: Webb, David C.
# Extracted name from listing: Weber, Beverly Marie
# Selected name: Weber, Beverly Marie
# Extracted name from listing: Weber, Jorg Mathias
# Selected name: Weber, Jorg Mathias
# Extracted name from listing: Webmoor, Timothy Aaron
# Selected name: Webmoor, Timothy Aaron
# Extracted name from listing: Wei, William
# Selected name: Wei, William
# Extracted name from listing: Weimer, Alan W.
# Selected name: Weimer, Alan W.
# Extracted name from listing: Weiser, Philip J.
# Selected name: Weiser, Philip J.
# Extracted name from listing: Weiss, Jeffrey B.
# Selected name: Weiss, Jeffrey B.
# Extracted name from listing: Weiss, Meta
# Selected name: Weiss, Meta
# Extracted name from listing: Welker, Cara
# Selected name: Welker, Cara Gonzalez
# Extracted name from listing: Welner, Kevin G.
# Selected name: Welner, Kevin G.
# Extracted name from listing: Welsh, Megan Elizabeth
# Error fetching https://experts.colorado.edu/display/fisid_153633: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_153633
# Extracted name from listing: Wenger, Paula
# Selected name: Wenger, Paula
# Extracted name from listing: Werner, LJ
# Selected name: Werner, LJ
# Extracted name from listing: Werner, Walter Bradley
# Selected name: Werner, Walter Bradley
# Extracted name from listing: Wessman, Carol A.
# Selected name: Wessman, Carol A.
# Extracted name from listing: West, Colin G.
# Selected name: West, Colin G.
# Extracted name from listing: Weston, Timothy B.
# Selected name: Weston, Timothy B.
# Extracted name from listing: Wherren, Anna Katherine
# Selected name: Wherren, Anna Katherine
# Extracted name from listing: Whisman, Mark
# Selected name: Whisman, Mark
# Extracted name from listing: White, Cindy Hagemeier
# Selected name: White, Cindy Hagemeier
# Extracted name from listing: White, James
# Selected name: White, James William Carl
# Extracted name from listing: White, Philip
# Selected name: White, Philip Bradley
# Extracted name from listing: White, Terrenda Corisa
# Selected name: White, Terrenda Corisa
# Extracted name from listing: White, Timothy J.
# Selected name: White, Timothy J.
# Extracted name from listing: Whitehead, Deborah Faith
# Selected name: Whitehead, Deborah Faith
# Extracted name from listing: Whitehead, Timothy Andrew
# Selected name: Whitehead, Timothy Andrew
# Extracted name from listing: Whiteley, Aaron
# Selected name: Whiteley, Aaron
# Extracted name from listing: Whiteley, Alexandra
# Selected name: Whiteley, Alexandra
# Extracted name from listing: Whiting, Gregory L.
# Selected name: Whiting, Gregory Lewis
# Extracted name from listing: Wieman, Carl E.
# Selected name: Wieman, Carl E.
# Extracted name from listing: Wiersma, Gabrielle Somnee
# Selected name: Wiersma, Gabrielle Somnee
# Extracted name from listing: Wiese, Annjeanette Michelle
# Selected name: Wiese, Annjeanette Michelle
# Extracted name from listing: Wilcox, Bethany R.
# Selected name: Wilcox, Bethany R.
# Extracted name from listing: Wilkerson, Donald
# Selected name: Wilkerson, Donald H
# Extracted name from listing: Wilkins, Helanius J.
# Selected name: Wilkins, Helanius J.
# Extracted name from listing: Willcutt, Erik G.
# Selected name: Willcutt, Erik G.
# Extracted name from listing: Williams, Christopher
# Selected name: Williams, Christopher
# Extracted name from listing: Williams, Lawrence Edwin Jr.
# Selected name: Williams, Lawrence Edwin Jr.
# Extracted name from listing: Willis, Erin
# Selected name: Willis, Erin
# Extracted name from listing: Willis, John Matthew
# Selected name: Willis, John Matthew
# Extracted name from listing: Willis, Michael John
# Selected name: Willis, Michael John
# Extracted name from listing: Wilson, Andrew
# Selected name: Wilson, Andrew D
# Extracted name from listing: Wilson, Terri Suzanne
# Selected name: Wilson, Terri Suzanne
# Extracted name from listing: Windell, Maria A.
# Selected name: Windell, Maria A.
# Extracted name from listing: Wineland, David J.
# Selected name: Wineland, David J.
# Extracted name from listing: Wing, Boswell A.
# Selected name: Wing, Boswell A.
# Extracted name from listing: Wingate, Kathryn
# Selected name: Wingate, Kathryn Anne
# Extracted name from listing: Wingo, Ajume
# Selected name: Wingo, Ajume
# Extracted name from listing: Winkiel, Laura Ann
# Selected name: Winkiel, Laura Ann
# Extracted name from listing: Winters, Andrew
# Selected name: Winters, Andrew
# Extracted name from listing: Wise, Jonathan
# Selected name: Wise, Jonathan
# Extracted name from listing: Wise, Matthew Eric
# Selected name: Wise, Matthew Eric
# Extracted name from listing: Wobbekind, Richard
# Selected name: Wobbekind, Richard
# Extracted name from listing: Womack, Mike Fitzgerald
# Selected name: Womack, Mike Fitzgerald
# Extracted name from listing: Wood, Peter H.
# Selected name: Wood, Peter H.
# Extracted name from listing: Wood, Tony
# Selected name: Wood, Tony
# Extracted name from listing: Wright Jr., Kenneth P.
# Selected name: Wright Jr., Kenneth P.
# Extracted name from listing: Wright, Nicole M.
# Selected name: Wright, Nicole Mansfield
# Extracted name from listing: Wustrow, Eric A.
# Selected name: Wustrow, Eric A.
# Extracted name from listing: Wuttke, Deborah S.
# Selected name: Wuttke, Deborah S.
# Extracted name from listing: Wyrod, Robert
# Selected name: Wyrod, Robert
# Extracted name from listing: Xi, Yunping
# Selected name: Xi, Yunping
# Extracted name from listing: Xiao, Jianliang
# Selected name: Xiao, Jianliang
# Extracted name from listing: Xu, Nicole
# Selected name: Xu, Nicole
# Extracted name from listing: Xu, Ping
# Selected name: Xu, Ping
# Extracted name from listing: Xue, Ding
# Selected name: Xue, Ding
# Extracted name from listing: Yamashita, Masano
# Selected name: Yamashita, Masano
# Extracted name from listing: Yannacito, Donald R.
# Selected name: Yannacito, Donald R.
# Extracted name from listing: Yazzie, Melanie A.
# Selected name: Yazzie, Melanie A.
# Extracted name from listing: Ye, Jun
# Selected name: Ye, Jun
# Extracted name from listing: Yeh, Emily Ting
# Selected name: Yeh, Emily Ting
# Extracted name from listing: Yeh, Tom
# Selected name: Yeh, Tom
# Extracted name from listing: Yilmaz, Ovunc
# Selected name: Yilmaz, Ovunc
# Extracted name from listing: Yonemoto, Marcia A.
# Selected name: Yonemoto, Marcia A.
# Extracted name from listing: York, Jeffrey Glenn
# Selected name: York, Jeffrey Glenn
# Extracted name from listing: Youkey, David
# Selected name: Youkey, David A
# Extracted name from listing: Young, Andrew P.
# Selected name: Young, Andrew P.
# Extracted name from listing: Young, Morgan
# Selected name: Young, Morgan
# Extracted name from listing: Young, Phoebe S.K.
# Selected name: Young, Phoebe S. K.
# Extracted name from listing: Young, Wendy Mores
# Selected name: Young, Wendy Mores
# Extracted name from listing: Yuan, Lei
# Selected name: Yuan, Lei
# Extracted name from listing: Yulsman, Thomas
# Selected name: Yulsman, Thomas
# Extracted name from listing: Zagona, Edith A.
# Selected name: Zagona, Edith A.
# Extracted name from listing: Zaharatos, Brian R.
# Selected name: Zaharatos, Brian R.
# Extracted name from listing: Zamore, Shaz
# Error fetching https://experts.colorado.edu/display/fisid_166083 : 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_166083%20
# Extracted name from listing: Zarske, Malinda Schaefer
# Selected name: Zarske, Malinda Schaefer
# Extracted name from listing: Zax, Jeffrey S.
# Selected name: Zax, Jeffrey S.
# Extracted name from listing: Zechman, Sarah Louise Center
# Selected name: Zechman, Sarah Louise Center
# Extracted name from listing: Zeiler, Thomas W.
# Selected name: Zeiler, Thomas W.
# Extracted name from listing: Zender, Jaime
# Selected name: Zender, Jaime  F.
# Extracted name from listing: Zerella, Michael
# Selected name: Zerella, Michael
# Extracted name from listing: Zhai, John Z.
# Selected name: Zhai, Zhiqiang (John)
# Extracted name from listing: Zhang, Dan
# Selected name: Zhang, Dan
# Extracted name from listing: Zhang, Huanan
# Selected name: Zhang, Huanan
# Extracted name from listing: Zhang, Rui
# Selected name: Zhang, Rui
# Extracted name from listing: Zhang, Wei
# Selected name: Zhang, Wei
# Extracted name from listing: Zhang, Xingtan
# Error fetching https://experts.colorado.edu/display/fisid_159295: 404 Client Error:  for url: https://experts.colorado.edu/display/fisid_159295
# Extracted name from listing: Zhang, Yida
# Selected name: Zhang, Yida
# Extracted name from listing: Zhong, Shijie
# Selected name: Zhong, Shijie
# Extracted name from listing: Ziemann, Paul Jeffrey
# Selected name: Ziemann, Paul Jeffrey
# Extracted name from listing: Zimmerman, Eric
# Selected name: Zimmerman, Eric D.
# Extracted name from listing: Zunger, Alexander
# Selected name: Zunger, Alexander
# Total extracted records: 1849
# Faculty list saved to uc_boulder_faculty2.xlsx
